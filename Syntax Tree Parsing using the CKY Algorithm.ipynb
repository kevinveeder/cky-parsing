# %% [markdown]
# # Syntax Tree Parsing using CKY
#
# ## Name: Kevin Veeder

# %% [markdown]
# For this project, I am building a simple parser trained on the ATIS (Air Traffic Information System) portion of the Penn Treebank. The training data consists of short queries and commands spoken by users interacting with a simulated robot travel agent.
#
# The key files involved and their roles are:
#
# - `train.trees.pre.unk`: Contains the training data trees — binary branching trees where all words appearing only once are replaced with <unk>.
#
# - `dev.strings`: Contains the strings for the development data set.
#
#
#
# ## What is CKY Parsing?
#
# CKY Parsing, named after its inventors John Cocke, Daniel Younger, and Tadao Kasami, is a widely-used algorithm for parsing sentences based on context-free grammars. Its efficiency and ability to handle ambiguous grammatical structures make it a fundamental technique in natural language processing.
#
# ## Importance in NLP
#
# Syntactic parsing — analyzing a sentence’s structure using formal grammar rules — is essential for understanding language. The CKY algorithm uses a bottom-up parsing approach to break down complex sentences into constituent parts, supporting tasks like machine translation, sentiment analysis, and information extraction. By implementing CKY Parsing, I am gaining insight into how computers process and interpret human language, a critical skill in NLP.

# %% [markdown]
# ## 01 - Setup
#
# To begin, I’m setting up the environment for the CKY Parsing process. This involves importing the necessary libraries and preparing everything needed to perform parsing.
#
# First, I import the required libraries and methods (ensuring they are installed beforehand):
#
#     - NLTK
#     - Tree from the nltk.tree
#     - ViterbiParser from nltk.parse
#     - svgling
#     - math

# %%
# Run these pip commands if you don't have these libraries installed already
# !pip install nltk
# !pip install svgling
# !pip install dill

# %%
import nltk
from nltk.tree import Tree
from nltk.parse import ViterbiParser
import svgling
import math

# %% [markdown]
# ## 02 - Importing and Visualizing the Syntax Tree
#
# ### What is a Syntax Tree?
#
# A syntax tree, also known as a parse tree, is a tree representation of the syntactic structure of a sentence. In linguistics and NLP, these trees are crucial for understanding how different parts of a sentence relate to each other according to the rules of grammar.
#
# ### Importance of Syntax Trees in NLP
#
# Syntax trees play a vital role in various NLP applications. They help in:
#
# - **Understanding Sentence Structure:** By breaking down a sentence into its constituent parts, syntax trees make it easier to analyze the grammatical structure.
# - **Improving Language Models:** They are essential in developing more accurate models for tasks like machine translation, speech recognition, and sentiment analysis.
# - **Information Extraction:** Syntax trees aid in extracting meaningful information from complex sentences, which is crucial in tasks like question answering and text summarization.
#
# ### Importing and Visualizing the Syntax Tree
#
#
# I start by importing a syntax tree from the provided file `train.trees.pre.unk` to visualize its structure. This helps deepen my understanding of sentence structure in NLP and the role syntax trees play in this process.
#
# 1. Read the First Line of the File: Using Python’s built-in `open` function, I access the file and read the first line, which contains the syntax tree of a sentence in a specific format. The command `first_line = file.readline().strip()` reads the line and removes any leading or trailing whitespace.
#
# 2. Parse the Syntax Tree: Next, I parse the string to create a syntax tree by applying the `Tree.fromstring(first_line)` method from NLTK. This converts the string representation into a Tree object, which I store in the variable `first_tree`.
#
# 3. Print the Partial Syntax Tree: Finally, I visualize the tree using the `pretty_print` method on the `first_tree object`.

# %%
with open("train.trees.pre.unk") as file:
    first_line = file.readline().strip()

first_tree = Tree.fromstring(first_line)
print(first_tree.pretty_print())
# Out:
#                                         TOP
#                  ________________________|_______________________________________________________
#                S_VP                                                                              |
#   ______________|________________________                                                        |
#  |                                       NP                                                      |
#  |         ______________________________|_________                                              |
#  |        |                                       NP*                                            |
#  |        |                 _______________________|_______                                      |
#  |        |                |                              NP*                                    |
#  |        |                |                  _____________|___________                          |
#  |        |                |                 |                        SBAR                       |
#  |        |                |                 |              ___________|____                     |
#  |        |                |                 |             |               S_VP                  |
#  |        |                |                 |             |       _________|____                |
#  |        NP               PP                PP            |      |              PP              |
#  |     ___|_____       ____|______        ___|_____        |      |          ____|_______        |
#  VB   DT       NNS    IN        NP_NNP   TO      NP_NNP WHNP_WDT VBP        IN         NP_NNP   PUNC
#  |    |         |     |           |      |         |       |      |         |            |       |
# List the     flights from     Baltimore  to     Seattle   that   stop       in      Minneapolis  .
#
# None

# %% [markdown]
# ## 03 - Convert Trees to Chomsky Normal Form (CNF) and Extract Productions
#
# In this stage of the project, I transform the syntax trees into Chomsky Normal Form (CNF) and extract grammatical productions from them. This transformation is an essential step in building a grammar that can be used for parsing.
#
# ### What is Chomsky Normal Form?
#
# Chomsky Normal Form is a way of rewriting and simplifying the grammar of a language. A grammar in CNF has its production rules restricted to a certain standard form. Specifically, each rule must be either:
# - A -> BC, where 'A', 'B', and 'C' are non-terminal symbols, and 'B' and 'C' are not the start symbol.
# - A -> a, where 'A' is a non-terminal symbol and 'a' is a terminal symbol.
# This form is particularly useful for parsing algorithms and simplifying the analysis of grammatical structures.
#
# ### Convert Trees to Chomsky Normal Form (CNF) and Extract Productions
#
# 1. Read Syntax Trees from File:
# I begin by reading all syntax trees from the `train.trees.pre.unk` file into a list, using the same approach as in the earlier step.
#
# 2. Convert Trees to CNF:
# Each tree is then converted into Chomsky Normal Form using the `Tree.chomsky_normal_form` method from the NLTK library, with the parameter `horzMarkov=2` to control binarization.
#
# 3. Extract Productions:
# After converting the trees to CNF, I extract the grammatical productions from them. These production rules define how sentences are constructed and are fundamental for building a formal grammar.
#
# I create a list called `productions` to collect all the rules. For each CNF tree, I use the `productions()` method to extract its grammatical rules and append them to the `productions` list. This collection of rules will later be used to construct the grammar for parsing.

# %%
with open("train.trees.pre.unk") as file:
    lines = file.readlines()
    lines = [line.rstrip('\n') for line in lines]

trees_list = []
for line in lines:
    trees = Tree.fromstring(line)
    trees_list.append(trees)

# %%
for trees in trees_list:
    trees = Tree.chomsky_normal_form(trees, horzMarkov=2)

# %%
productions = []
for trees in trees_list:
    rules = trees.productions()
    for rule in rules:
        productions.append(rule)

productions
# Out:
# [TOP -> S_VP PUNC,
#  S_VP -> VB NP,
#  VB -> 'List',
#  NP -> NP NP*,
#  NP -> DT NNS,
#  DT -> 'the',
#  NNS -> 'flights',
#  NP* -> PP NP*,
#  PP -> IN NP_NNP,
#  IN -> 'from',
#  NP_NNP -> 'Baltimore',
#  NP* -> PP SBAR,
#  PP -> TO NP_NNP,
#  TO -> 'to',
#  NP_NNP -> 'Seattle',
#  SBAR -> WHNP_WDT S_VP,
#  WHNP_WDT -> 'that',
#  S_VP -> VBP PP,
#  VBP -> 'stop',
#  PP -> IN NP_NNP,
#  IN -> 'in',
#  NP_NNP -> 'Minneapolis',
#  PUNC -> '.',
#  TOP -> SQ PUNC,
#  SQ -> VBZ SQ*,
#  VBZ -> 'Does',
#  SQ* -> NP VP,
#  NP -> DT NN,
#  DT -> 'this',
#  NN -> 'flight',
#  VP -> VB NP_NN,
#  VB -> 'serve',
#  NP_NN -> 'dinner',
#  PUNC -> '?',
#  TOP -> S PUNC,
#  S -> NP_PRP VP,
#  NP_PRP -> 'I',
#  VP -> VBP NP,
#  VBP -> 'need',
#  NP -> NP NP*,
#  NP -> DT NN,
#  DT -> 'a',
#  NN -> 'flight',
#  NP* -> PP NP*,
#  PP -> TO NP_NNP,
#  TO -> 'to',
#  NP_NNP -> 'Seattle',
#  NP* -> VP VP,
#  VP -> VBG PP,
#  VBG -> 'leaving',
#  PP -> IN NP_NNP,
#  IN -> 'from',
#  NP_NNP -> 'Baltimore',
#  VP -> VBG NP,
#  VBG -> '<unk>',
#  NP -> NP PP,
#  NP -> DT NN,
#  DT -> 'a',
#  NN -> 'stop',
#  PP -> IN NP_NNP,
#  IN -> 'in',
#  NP_NNP -> 'Minneapolis',
#  PUNC -> '.',
#  TOP -> S PUNC,
#  S -> NP_PRP VP,
#  NP_PRP -> 'I',
#  VP -> VBP S_VP,
#  VBP -> 'need',
#  S_VP -> TO VP,
#  TO -> 'to',
#  VP -> VB S,
#  VB -> 'have',
#  S -> NP_NN VP_VBN,
#  NP_NN -> 'dinner',
#  VP_VBN -> 'served',
#  PUNC -> '.',
#  TOP -> S PUNC,
#  S -> NP_PRP VP,
#  NP_PRP -> 'I',
#  VP -> VBP NP,
#  VBP -> 'have',
#  NP -> NP SBAR,
#  NP -> CD NNS,
#  CD -> 'two',
#  NNS -> '<unk>',
#  SBAR -> WHNP_WDT S_VP,
#  WHNP_WDT -> 'that',
#  S_VP -> MD VP,
#  MD -> 'would',
#  VP -> VB S_VP,
#  VB -> 'like',
#  S_VP -> TO VP,
#  TO -> 'to',
#  VP -> VB VP*,
#  VB -> 'visit',
#  VP* -> NP_PRP VP*,
#  NP_PRP -> 'me',
#  VP* -> PP ADVP,
#  PP -> IN NP_NNP,
#  IN -> 'on',
#  NP_NNP -> 'Wednesday',
#  ADVP -> ADVP_RB PP,
#  ADVP_RB -> 'here',
#  PP -> IN NP,
#  IN -> 'in',
#  NP -> NP_NNP NP,
#  NP_NNP -> 'Washington',
#  NP -> NNP NNP,
#  NNP -> 'D',
#  NNP -> 'C',
#  PUNC -> '.',
#  TOP -> S PUNC,
#  S -> S S*,
#  S -> NP VP,
#  NP -> NP_CD PP,
#  NP_CD -> 'one',
#  PP -> IN NP_PRP,
#  IN -> 'of',
#  NP_PRP -> '<unk>',
#  VP -> VBZ PP,
#  VBZ -> 'lives',
#  PP -> IN NP_NNP,
#  IN -> 'in',
#  NP_NNP -> 'Denver',
#  S* -> CC S,
#  CC -> 'and',
#  S -> NP VP,
#  NP -> DT JJ,
#  DT -> 'the',
#  JJ -> 'other',
#  VP -> VBZ PP,
#  VBZ -> 'lives',
#  PP -> IN NP_NNP,
#  IN -> 'in',
#  NP_NNP -> 'Miami',
#  PUNC -> '.',
#  TOP -> S PUNC,
#  S -> NP_PRP VP,
#  NP_PRP -> 'I',
#  VP -> VBP NP,
#  VBP -> 'have',
#  NP -> NP NP*,
#  NP -> DT NN,
#  DT -> 'a',
#  NN -> '<unk>',
#  NP* -> VP SBAR,
#  VP -> VBG PP,
#  VBG -> '<unk>',
#  PP -> IN NP_NNP,
#  IN -> 'in',
#  NP_NNP -> 'Denver',
#  SBAR -> WHNP_WDT S_VP,
#  WHNP_WDT -> 'that',
#  S_VP -> MD VP,
#  MD -> 'would',
#  VP -> VB S_VP,
#  VB -> 'like',
#  S_VP -> TO VP,
#  TO -> 'to',
#  VP -> VB VP*,
#  VB -> 'visit',
#  VP* -> NP_PRP ADVP,
#  NP_PRP -> 'me',
#  ADVP -> ADVP_RB PP,
#  ADVP_RB -> 'here',
#  PP -> IN NP,
#  IN -> 'in',
#  NP -> NP_NNP NP,
#  NP_NNP -> 'Washington',
#  NP -> NNP NNP,
#  NNP -> 'D',
#  NNP -> 'C',
#  PUNC -> '.',
#  TOP -> S PUNC,
#  S -> NP_PRP VP,
#  NP_PRP -> 'I',
#  VP -> VBP NP,
#  VBP -> 'need',
#  NP -> NP NP*,
#  NP -> DT NN,
#  DT -> 'a',
#  NN -> 'flight',
#  NP* -> PP NP*,
#  PP -> IN NP_NNP,
#  IN -> 'from',
#  NP_NNP -> 'Indianapolis',
#  NP* -> PP PP,
#  PP -> TO NP_NNP,
#  TO -> 'to',
#  NP_NNP -> 'Houston',
#  PP -> IN NP,
#  IN -> 'on',
#  NP -> NNP NP*,
#  NNP -> 'T',
#  NP* -> NNP NNP,
#  NNP -> 'W',
#  NNP -> 'A',
#  PUNC -> '.',
#  TOP -> S PUNC,
#  S -> NP VP,
#  NP -> DT NN,
#  DT -> 'The',
#  NN -> 'flight',
#  VP -> MD VP,
#  MD -> 'should',
#  VP -> VB VP*,
#  VB -> 'arrive',
#  VP* -> PP NP_NN,
#  PP -> IN NP,
#  IN -> 'at',
#  NP -> QP RB,
#  QP -> RB CD,
#  RB -> 'around',
#  CD -> 'eleven',
#  RB -> 'a.m',
#  NP_NN -> 'tomorrow',
#  PUNC -> '.',
#  TOP -> S PUNC,
#  S -> NP_PRP VP,
#  NP_PRP -> 'I',
#  VP -> VBP NP,
#  VBP -> 'need',
#  NP -> NP NP*,
#  NP -> DT NN,
#  DT -> 'a',
#  NN -> 'flight',
#  NP* -> PP NP*,
#  PP -> IN NP_NNP,
#  IN -> 'from',
#  NP_NNP -> 'Atlanta',
#  NP* -> PP NP,
#  PP -> TO NP,
#  TO -> 'to',
#  NP -> NP_NNP NP,
#  NP_NNP -> 'Charlotte',
#  NP -> NNP NNP,
#  NNP -> '<unk>',
#  NNP -> '<unk>',
#  NP -> JJ NNP,
#  JJ -> 'next',
#  NNP -> 'Monday',
#  PUNC -> '.',
#  TOP -> S PUNC,
#  S -> NP_PRP VP,
#  NP_PRP -> 'I',
#  VP -> VBP S_VP,
#  VBP -> 'need',
#  S_VP -> TO VP,
#  TO -> 'to',
#  VP -> VB VP*,
#  VB -> 'arrive',
#  VP* -> PP PP,
#  PP -> IN NP_NNP,
#  IN -> 'at',
#  NP_NNP -> 'Charlotte',
#  PP -> IN NP,
#  IN -> 'at',
#  NP -> QP RB,
#  QP -> RB CD,
#  RB -> 'around',
#  CD -> 'five',
#  RB -> 'p.m',
#  PUNC -> '.',
#  TOP -> S PUNC,
#  S -> NP_PRP VP,
#  NP_PRP -> 'I',
#  VP -> VBP S_VP,
#  VBP -> 'need',
#  S_VP -> TO VP,
#  TO -> 'to',
#  VP -> VB PP,
#  VB -> 'return',
#  PP -> IN NP_NNP,
#  IN -> 'on',
#  NP_NNP -> 'Tuesday',
#  PUNC -> '.',
#  TOP -> S PUNC,
#  S -> NP VP,
#  NP -> DT NP*,
#  DT -> 'The',
#  NP* -> NN NN,
#  NN -> 'return',
#  NN -> 'flight',
#  VP -> MD VP,
#  MD -> 'should',
#  VP -> VB PP,
#  VB -> 'leave',
#  PP -> IN NP,
#  IN -> 'at',
#  NP -> QP RB,
#  QP -> RB CD,
#  RB -> 'around',
#  CD -> 'seven',
#  RB -> 'p.m',
#  PUNC -> '.',
#  TOP -> SBARQ PUNC,
#  SBARQ -> WHNP SQ,
#  WHNP -> WHNP ADJP_JJ,
#  WHNP -> WRB RB,
#  WRB -> 'How',
#  RB -> 'much',
#  ADJP_JJ -> '<unk>',
#  SQ -> MD SQ*,
#  MD -> 'would',
#  SQ* -> NP VP_VB,
#  NP -> DT NP*,
#  DT -> 'a',
#  NP* -> JJ NP*,
#  JJ -> 'first',
#  NP* -> NN NN,
#  NN -> 'class',
#  NN -> 'fare',
#  VP_VB -> 'cost',
#  PUNC -> '?',
#  TOP -> SBARQ PUNC,
#  SBARQ -> WHNP SQ,
#  WHNP -> WRB RB,
#  WRB -> 'How',
#  RB -> 'much',
#  SQ -> MD SQ*,
#  MD -> 'would',
#  SQ* -> NP VP_VB,
#  NP -> DT NP*,
#  DT -> 'the',
#  NP* -> NN NN,
#  NN -> 'coach',
#  NN -> 'fare',
#  VP_VB -> 'cost',
#  PUNC -> '?',
#  TOP -> S PUNC,
#  S -> NP_PRP VP,
#  NP_PRP -> 'I',
#  VP -> MD VP,
#  MD -> 'would',
#  VP -> VB S_VP,
#  VB -> 'like',
#  S_VP -> TO VP,
#  TO -> 'to',
#  VP -> VB NP,
#  VB -> 'find',
#  NP -> NP SBAR,
#  NP -> DT NN,
#  DT -> 'a',
#  NN -> 'flight',
#  SBAR -> WHNP_WDT S_VP,
#  WHNP_WDT -> 'that',
#  S_VP -> VBZ VP*,
#  VBZ -> '<unk>',
#  VP* -> PP PP,
#  PP -> IN NP_NNP,
#  IN -> 'from',
#  NP_NNP -> 'Boston',
#  PP -> TO NP_NNP,
#  TO -> 'to',
#  NP_NNP -> 'Orlando',
#  PUNC -> '.',
#  TOP -> S PUNC,
#  S -> NP_PRP VP,
#  NP_PRP -> 'I',
#  VP -> MD VP,
#  MD -> 'would',
#  VP -> VB S,
#  VB -> 'like',
#  S -> NP VP,
#  NP -> DT NN,
#  DT -> 'the',
#  NN -> 'flight',
#  VP -> TO VP,
#  TO -> 'to',
#  VP -> VP VP*,
#  VP -> VB PP,
#  VB -> 'be',
#  PP -> IN NP,
#  IN -> 'on',
#  NP -> NNP NNP,
#  NNP -> 'United',
#  NNP -> 'Airlines',
#  VP* -> CC VP,
#  CC -> 'and',
#  VP -> VB VP*,
#  VB -> 'arrive',
#  VP* -> PP PP,
#  PP -> IN NP,
#  IN -> 'in',
#  NP -> NNP NNP,
#  NNP -> 'San',
#  NNP -> 'Jose',
#  PP -> IN NP,
#  IN -> 'around',
#  NP -> CD RB,
#  CD -> 'ten',
#  RB -> 'p.m',
#  PUNC -> '.',
#  TOP -> S PUNC,
#  S -> NP_PRP VP,
#  NP_PRP -> 'I',
#  VP -> MD VP,
#  MD -> 'would',
#  VP -> VB S_VP,
#  VB -> 'like',
#  S_VP -> TO VP,
#  TO -> 'to',
#  VP -> VB VP*,
#  VB -> 'find',
#  VP* -> PRT_RP NP,
#  PRT_RP -> '<unk>',
#  NP -> NP PP,
#  NP -> DT NP*,
#  DT -> 'the',
#  NP* -> NN NN,
#  NN -> 'flight',
#  NN -> 'number',
#  PP -> IN NP,
#  IN -> 'for',
#  NP -> NP SBAR,
#  NP -> DT NP*,
#  DT -> 'the',
#  NP* -> NNP NN,
#  NNP -> 'United',
#  NN -> 'flight',
#  SBAR -> WHNP_WDT S_VP,
#  WHNP_WDT -> 'that',
#  S_VP -> VBZ VP*,
#  VBZ -> 'arrives',
#  VP* -> PP PP,
#  PP -> IN NP,
#  IN -> 'in',
#  NP -> NNP NNP,
#  NNP -> 'San',
#  NNP -> 'Jose',
#  PP -> IN NP,
#  IN -> 'around',
#  NP -> CD RB,
#  CD -> 'ten',
#  RB -> 'p.m',
#  PUNC -> '.',
#  TOP -> S_VP PUNC,
#  S_VP -> VB VP*,
#  VB -> 'Show',
#  VP* -> NP_PRP NP,
#  NP_PRP -> 'me',
#  NP -> NP VP,
#  NP -> PDT NP*,
#  PDT -> 'all',
#  NP* -> DT NNS,
#  DT -> 'the',
#  NNS -> 'flights',
#  VP -> VBG NP_NNP,
#  VBG -> 'leaving',
#  NP_NNP -> 'Baltimore',
#  PUNC -> '.',
#  TOP -> S_VP PUNC,
#  S_VP -> VB VP*,
#  VB -> 'Show',
#  VP* -> NP_PRP NP,
#  NP_PRP -> 'me',
#  NP -> NP SBAR,
#  NP -> PDT NP*,
#  PDT -> 'all',
#  NP* -> DT NNS,
#  DT -> 'the',
#  NNS -> 'flights',
#  SBAR -> WHNP_WDT S_VP,
#  WHNP_WDT -> 'that',
#  S_VP -> VB VP*,
#  VB -> 'go',
#  VP* -> PP PP,
#  PP -> IN NP_NNP,
#  IN -> 'from',
#  NP_NNP -> 'Baltimore',
#  PP -> TO NP_NNP,
#  TO -> 'to',
#  NP_NNP -> 'Seattle',
#  PUNC -> '.',
#  TOP -> SBARQ PUNC,
#  SBARQ -> PP SBARQ*,
#  PP -> IN NP,
#  IN -> '<unk>',
#  NP -> DT NNS,
#  DT -> 'those',
#  NNS -> 'flights',
#  SBARQ* -> WHNP_WHNP SQ_VP,
#  WHNP_WHNP -> WDT NNS,
#  WDT -> '<unk>',
#  NNS -> 'ones',
#  SQ_VP -> VBP PP,
#  VBP -> 'stop',
#  PP -> IN NP_NNP,
#  IN -> 'in',
#  NP_NNP -> 'Minneapolis',
#  PUNC -> '?',
#  TOP -> SQ PUNC,
#  SQ -> VBZ SQ*,
#  VBZ -> 'Does',
#  SQ* -> NP VP,
#  NP -> DT NN,
#  DT -> 'that',
#  NN -> 'flight',
#  VP -> VB NP_NN,
#  VB -> 'serve',
#  NP_NN -> 'dinner',
#  PUNC -> '?',
#  TOP -> SBARQ PUNC,
#  SBARQ -> WHNP_WP SQ,
#  WHNP_WP -> 'What',
#  SQ -> VBP NP,
#  VBP -> 'are',
#  NP -> NP NP*,
#  NP -> DT NNS,
#  DT -> 'the',
#  NNS -> 'flights',
#  NP* -> PP PP,
#  PP -> IN NP_NNP,
#  IN -> 'from',
#  NP_NNP -> 'Milwaukee',
#  PP -> TO NP_NNP,
#  TO -> 'to',
#  NP_NNP -> 'Tampa',
#  PUNC -> '?',
#  TOP -> SBARQ PUNC,
#  SBARQ -> WHNP SQ_VP,
#  WHNP -> WHNP_WDT PP,
#  WHNP_WDT -> 'Which',
#  PP -> IN NP_DT,
#  IN -> 'of',
#  NP_DT -> 'these',
#  SQ_VP -> VBP PP,
#  VBP -> 'stop',
#  PP -> IN NP_NNP,
#  IN -> 'in',
#  NP_NNP -> 'Nashville',
#  PUNC -> '?',
#  TOP -> S_VP PUNC,
#  S_VP -> VB VP*,
#  VB -> 'Show',
#  VP* -> NP_PRP NP,
#  NP_PRP -> 'me',
#  NP -> NP NP*,
#  NP -> DT NNS,
#  DT -> 'the',
#  NNS -> 'flights',
#  NP* -> PP NP*,
#  PP -> IN NP,
#  IN -> 'from',
#  NP -> NP_NNP NP,
#  NP_NNP -> 'Newark',
#  NP -> NNP NNP,
#  NNP -> 'New',
#  NNP -> 'Jersey',
#  NP* -> PP NP,
#  PP -> TO NP,
#  TO -> 'to',
#  NP -> NNP NNP,
#  NNP -> 'Ontario',
#  NNP -> 'International',
#  NP -> JJ NNP,
#  JJ -> 'next',
#  NNP -> 'Saturday',
#  PUNC -> '.',
#  TOP -> SBARQ PUNC,
#  SBARQ -> WHNP SQ_VP,
#  WHNP -> WHNP_WDT PP,
#  WHNP_WDT -> 'Which',
#  PP -> IN NP_DT,
#  IN -> 'of',
#  NP_DT -> 'these',
#  SQ_VP -> VP VP*,
#  VP -> VBP PP,
#  VBP -> 'leave',
#  PP -> IN NP_NN,
#  IN -> 'after',
#  NP_NN -> 'noon',
#  VP* -> CC VP,
#  CC -> 'and',
#  VP -> VBP PP,
#  VBP -> 'stop',
#  PP -> IN NP_NNP,
#  IN -> 'in',
#  NP_NNP -> 'Phoenix',
#  PUNC -> '?',
#  TOP -> S_VP PUNC,
#  S_VP -> VB VP*,
#  VB -> 'Show',
#  VP* -> NP_PRP NP,
#  NP_PRP -> 'me',
#  NP -> NP NP*,
#  NP -> DT NNS,
#  DT -> 'the',
#  NNS -> 'flights',
#  NP* -> PP PP,
#  PP -> IN NP_NNP,
#  IN -> 'from',
#  NP_NNP -> 'Montreal',
#  PP -> TO NP_NNP,
#  TO -> 'to',
#  NP_NNP -> 'Chicago',
#  PUNC -> '.',
#  TOP -> S_VP PUNC,
#  S_VP -> VB VP*,
#  VB -> 'Show',
#  VP* -> NP_PRP NP,
#  NP_PRP -> 'me',
#  NP -> NP NP*,
#  NP -> DT NNS,
#  DT -> 'the',
#  NNS -> 'flights',
#  NP* -> PP PP,
#  PP -> IN NP_NNP,
#  IN -> 'from',
#  NP_NNP -> 'Chicago',
#  PP -> TO NP_NNP,
#  TO -> 'to',
#  NP_NNP -> 'Indianapolis',
#  PUNC -> '.',
#  TOP -> S_VP PUNC,
#  S_VP -> VB VP*,
#  VB -> 'Show',
#  VP* -> NP_PRP NP,
#  NP_PRP -> 'me',
#  NP -> NP NP*,
#  NP -> DT NNS,
#  DT -> 'the',
#  NNS -> 'flights',
#  NP* -> PP PP,
#  PP -> IN NP_NNP,
#  IN -> 'from',
#  NP_NNP -> 'Indianapolis',
#  PP -> TO NP_NNP,
#  TO -> 'to',
#  NP_NNP -> 'Montreal',
#  PUNC -> '.',
#  TOP -> S_VP PUNC,
#  S_VP -> VB VP*,
#  VB -> '<unk>',
#  VP* -> NP_PRP PP,
#  NP_PRP -> 'me',
#  PP -> IN NP,
#  IN -> 'about',
#  NP -> NP PP,
#  NP -> DT NP*,
#  DT -> 'the',
#  NP* -> NN NP*,
#  NN -> 'ground',
#  NP* -> NN NN,
#  NN -> 'ground',
#  NN -> 'transportation',
#  PP -> IN NP_NNP,
#  IN -> 'in',
#  NP_NNP -> 'Chicago',
#  PUNC -> '.',
#  TOP -> FRAG PUNC,
#  FRAG -> X PP,
#  X -> WP IN,
#  WP -> 'What',
#  IN -> 'about',
#  PP -> IN NP_NNP,
#  IN -> 'in',
#  NP_NNP -> 'Indianapolis',
#  PUNC -> '.',
#  TOP -> SBARQ PUNC,
#  SBARQ -> WHNP_WHNP SQ,
#  WHNP_WHNP -> WDT NNS,
#  WDT -> 'What',
#  NNS -> 'flights',
#  SQ -> VBP SQ*,
#  VBP -> 'do',
#  SQ* -> NP_PRP VP,
#  NP_PRP -> 'you',
#  VP -> VB VP*,
#  VB -> 'have',
#  VP* -> PP PP,
#  PP -> IN NP_NNP,
#  IN -> 'from',
#  NP_NNP -> 'Milwaukee',
#  PP -> TO NP_NNP,
#  TO -> 'to',
#  NP_NNP -> 'Tampa',
#  PUNC -> '?',
#  TOP -> S_VP PUNC,
#  S_VP -> VB NP_PRP,
#  VB -> 'Thank',
#  NP_PRP -> 'you',
#  PUNC -> '.',
#  TOP -> SBARQ PUNC,
#  SBARQ -> WHNP SQ,
#  WHNP -> WDT NN,
#  WDT -> 'what',
#  NN -> 'time',
#  SQ -> VBZ NP_PRP,
#  VBZ -> 'is',
#  NP_PRP -> 'it',
#  PUNC -> '?',
#  TOP -> S_VP PUNC,
#  S_VP -> VB VP*,
#  VB -> 'Show',
#  VP* -> NP_PRP NP,
#  NP_PRP -> 'me',
#  NP -> NP NP*,
#  NP -> DT NNS,
#  DT -> 'the',
#  NNS -> 'flights',
#  NP* -> PP PP,
#  PP -> IN NP_NNP,
#  IN -> 'from',
#  NP_NNP -> 'Baltimore',
#  PP -> TO NP_NNP,
#  TO -> 'to',
#  NP_NNP -> 'Seattle',
#  PUNC -> '.',
#  TOP -> SBARQ PUNC,
#  SBARQ -> WHNP_WDT SQ,
#  WHNP_WDT -> 'Which',
#  SQ -> VBP NP,
#  VBP -> 'are',
#  NP -> NP SBAR,
#  NP -> DT NNS,
#  DT -> 'the',
#  NNS -> 'flights',
#  SBAR -> WHNP_WDT S_VP,
#  WHNP_WDT -> 'that',
#  S_VP -> VBP NP,
#  VBP -> 'make',
#  NP -> NP PP,
#  NP -> DT NN,
#  DT -> 'a',
#  NN -> 'stop',
#  PP -> IN NP_NNP,
#  IN -> 'in',
#  NP_NNP -> 'Minneapolis',
#  PUNC -> '?',
#  TOP -> SQ PUNC,
#  SQ -> VBZ SQ*,
#  VBZ -> 'Does',
#  SQ* -> NP VP,
#  NP -> DT NN,
#  DT -> 'that',
#  NN -> 'flight',
#  VP -> VB NP_NN,
#  VB -> 'serve',
#  NP_NN -> 'dinner',
#  PUNC -> '?',
#  TOP -> S_VP PUNC,
#  S_VP -> VB NP,
#  VB -> '<unk>',
#  NP -> DT NN,
#  DT -> 'that',
#  NN -> 'flight',
#  PUNC -> '.',
#  TOP -> S PUNC,
#  S -> NP_PRP VP,
#  NP_PRP -> 'I',
#  VP -> MD VP,
#  MD -> 'would',
#  VP -> VB S_VP,
#  VB -> 'like',
#  S_VP -> TO VP,
#  TO -> 'to',
#  VP -> VB VP*,
#  VB -> 'travel',
#  VP* -> PP PP,
#  PP -> IN NP_NNP,
#  IN -> 'from',
#  NP_NNP -> 'Indianapolis',
#  PP -> TO NP_NNP,
#  TO -> 'to',
#  NP_NNP -> 'Houston',
#  PUNC -> '.',
#  TOP -> S PUNC,
#  S -> NP VP,
#  NP -> DT NN,
#  DT -> 'The',
#  NN -> 'flight',
#  VP -> MD VP,
#  MD -> 'should',
#  VP -> VB PP,
#  VB -> 'arrive',
#  PP -> IN NP,
#  IN -> 'around',
#  NP -> CD NP*,
#  CD -> 'ten',
#  NP* -> CC NP*,
#  CC -> 'or',
#  NP* -> CD RB,
#  CD -> 'eleven',
#  RB -> 'a.m',
#  PUNC -> '.',
#  TOP -> S_VP PUNC,
#  S_VP -> VB VP*,
#  VB -> 'Show',
#  VP* -> NP_PRP NP,
#  NP_PRP -> 'me',
#  NP -> DT NP*,
#  DT -> 'the',
#  NP* -> JJ NN,
#  JJ -> 'first',
#  NN -> 'one',
#  PUNC -> '.',
#  TOP -> SBARQ PUNC,
#  SBARQ -> WHNP_WDT SQ,
#  WHNP_WDT -> 'Which',
#  SQ -> VBZ NP,
#  VBZ -> 'is',
#  NP -> NP VP,
#  NP -> DT NN,
#  DT -> 'the',
#  NN -> 'aircraft',
#  VP -> VBN PP,
#  VBN -> '<unk>',
#  PP -> IN NP,
#  IN -> 'by',
#  NP -> DT NN,
#  DT -> 'this',
#  NN -> 'flight',
#  PUNC -> '?',
#  TOP -> S PUNC,
#  S -> NP_PRP VP,
#  NP_PRP -> 'I',
#  VP -> VBP ADJP,
#  VBP -> '<unk>',
#  ADJP -> JJ PP,
#  JJ -> '<unk>',
#  PP -> IN NP,
#  IN -> 'in',
#  NP -> NP NP*,
#  NP -> DT NN,
#  DT -> 'a',
#  NN -> 'flight',
#  NP* -> PP PP,
#  PP -> IN NP_NNP,
#  IN -> 'from',
#  NP_NNP -> 'Cincinnati',
#  PP -> TO NP_NNP,
#  TO -> 'to',
#  NP_NNP -> 'Burbank',
#  PUNC -> '.',
#  TOP -> S PUNC,
#  S -> NP VP,
#  NP -> DT NN,
#  DT -> 'the',
#  NN -> 'flight',
#  VP -> MD VP,
#  MD -> 'should',
#  VP -> VP VP*,
#  VP -> VB NP_NNP,
#  VB -> 'be',
#  NP_NNP -> 'American',
#  VP* -> CC VP,
#  CC -> 'and',
#  VP -> VB PP,
#  VB -> 'leave',
#  PP -> IN NP,
#  IN -> 'in',
#  NP -> DT NN,
#  DT -> 'the',
#  NN -> 'afternoon',
#  PUNC -> '.',
#  TOP -> S PUNC,
#  S -> NP_PRP VP,
#  NP_PRP -> 'I',
#  VP -> VBP S_VP,
#  VBP -> 'need',
#  S_VP -> TO VP,
#  TO -> 'to',
#  VP -> VB NP,
#  VB -> '<unk>',
#  NP -> DT NX,
#  DT -> 'the',
#  NX -> NX_NN NX*,
#  NX_NN -> 'aircraft',
#  NX* -> CC NX,
#  CC -> 'and',
#  NX -> NN NN,
#  NN -> 'flight',
#  NN -> 'number',
#  PUNC -> '.',
#  TOP -> S PUNC,
#  S -> NP_PRP VP,
#  NP_PRP -> 'I',
#  VP -> VBP NP,
#  VBP -> 'need',
#  NP -> NP NP*,
#  NP -> DT NN,
#  DT -> 'a',
#  NN -> 'flight',
#  NP* -> PP NP*,
#  PP -> IN NP,
#  IN -> 'from',
#  NP -> NNP NNP,
#  NNP -> 'Los',
#  NNP -> 'Angeles',
#  NP* -> PP NP_NN,
#  PP -> TO NP_NNP,
#  TO -> 'to',
#  NP_NNP -> 'Charlotte',
#  NP_NN -> 'today',
#  PUNC -> '.',
#  TOP -> S PUNC,
#  S -> NP_PRP VP,
#  NP_PRP -> 'I',
#  VP -> VBP NP,
#  VBP -> 'need',
#  NP -> NP NP*,
#  NP -> DT NN,
#  DT -> 'a',
#  NN -> 'flight',
#  NP* -> PP NP*,
#  PP -> IN NP_NNP,
#  IN -> 'from',
#  NP_NNP -> 'Charlotte',
#  NP* -> PP VP,
#  PP -> TO NP_NNP,
#  TO -> 'to',
#  NP_NNP -> 'Newark',
#  VP -> VBG NP,
#  VBG -> 'leaving',
#  NP -> NN NN,
#  NN -> 'today',
#  NN -> 'evening',
#  PUNC -> '.',
#  TOP -> S PUNC,
#  S -> NP_PRP VP,
#  NP_PRP -> 'I',
#  VP -> VBP NP,
#  VBP -> 'need',
#  NP -> NP NP*,
#  NP -> DT NN,
#  DT -> 'a',
#  NN -> 'flight',
#  NP* -> PP NP*,
#  PP -> IN NP_NNP,
#  IN -> 'from',
#  NP_NNP -> 'Newark',
#  NP* -> PP VP,
#  PP -> TO NP,
#  TO -> 'to',
#  NP -> NNP NNP,
#  NNP -> 'Los',
#  NNP -> 'Angeles',
#  VP -> VBG NP,
#  VBG -> 'leaving',
#  NP -> NN NN,
#  NN -> 'tomorrow',
#  NN -> 'evening',
#  PUNC -> '.',
#  TOP -> SQ PUNC,
#  SQ -> VBP SQ*,
#  VBP -> 'Do',
#  SQ* -> NP VP,
#  NP -> DT NNS,
#  DT -> 'any',
#  NNS -> 'flights',
#  VP -> VB PP,
#  VB -> 'stop',
#  PP -> IN NP_NNP,
#  IN -> 'in',
#  NP_NNP -> 'Chicago',
#  PUNC -> '?',
#  TOP -> SBARQ PUNC,
#  SBARQ -> WHNP SQ_VP,
#  WHNP -> WDT NNS,
#  WDT -> 'What',
#  NNS -> 'meals',
#  SQ_VP -> VBP VP,
#  VBP -> 'are',
#  VP -> VBN PP,
#  VBN -> 'served',
#  PP -> IN NP,
#  IN -> 'on',
#  NP -> DT NNS,
#  DT -> 'these',
#  NNS -> 'flights',
#  PUNC -> '?',
#  TOP -> SBARQ PUNC,
#  SBARQ -> WHNP_WHNP SQ,
#  WHNP_WHNP -> WDT NNS,
#  WDT -> 'What',
#  NNS -> 'flights',
#  SQ -> VBP SQ*,
#  VBP -> 'do',
#  SQ* -> NP_PRP VP,
#  NP_PRP -> 'you',
#  VP -> VB VP*,
#  VB -> 'have',
#  VP* -> PP VP*,
#  PP -> IN NP_NNP,
#  IN -> 'from',
#  NP_NNP -> 'Burbank',
#  VP* -> X_TO PP,
#  X_TO -> 'to',
#  PP -> TO NP,
#  TO -> 'to',
#  NP -> NP_NNP NP_NNP,
#  NP_NNP -> 'Tacoma',
#  NP_NNP -> 'Washington',
#  PUNC -> '?',
#  TOP -> S PUNC,
#  S -> NP_PRP VP,
#  NP_PRP -> 'I',
#  VP -> MD VP,
#  MD -> 'would',
#  ...]

# %% [markdown]
# ## 04 - Inducing a Probabilistic Context-Free Grammar (PCFG) from Productions
#
# After extracting the productions from the CNF trees, the next critical step is to induce a Probabilistic Context-Free Grammar (PCFG) from those productions. This is a key component of syntactic parsing in NLP.
#
# ### What is a Probabilistic Context-Free Grammar (PCFG)?
#
# A PCFG extends the standard context-free grammar by associating probabilities with each production rule. These probabilities reflect how often each rule is used in the language data, allowing the grammar to capture the statistical tendencies of natural language. This makes PCFGs especially effective for modeling linguistic structures and managing syntactic ambiguity.
#
# ### Importance of PCFG in NLP
#
# In NLP, PCFGs are instrumental for several reasons:
# - **Handling Ambiguity:** They help in dealing with ambiguities inherent in natural languages by preferring more likely structures over less likely ones.
# - **Improving Parsing Accuracy:** PCFGs enhance the accuracy of parsing algorithms, making them more effective in understanding complex sentences.
# - **Application in Various NLP Tasks:** They are fundamental in tasks such as machine translation, speech recognition, and syntactic analysis.
#
# ### Steps to Induce a PCFG from Productions:
#
# 1. Define the Start Symbol:
# I identify the start symbol used in the syntax trees (e.g., by reviewing the earlier tree visualization) and create a nonterminal using `nltk.Nonterminal`.
#
# 2. Induce the PCFG:
# Using the `induce_pcfg` function from NLTK, I generate the PCFG by passing in the start symbol and the list of extracted `productions`. The resulting grammar is stored in a variable named grammar.
#
# 3. Display Sample Grammar Rules:
# To examine the structure of the induced grammar, I print out the first 10 grammar rules as a sample.

# %%
nonterminal_symbol = nltk.Nonterminal('TOP')

# %%
grammar = nltk.induce_pcfg(nonterminal_symbol, productions)

# %%
grammar.productions()
# Out:
# [TOP -> S_VP PUNC [0.208955],
#  S_VP -> VB NP [0.122302],
#  VB -> 'List' [0.0180723],
#  NP -> NP NP* [0.115942],
#  NP -> DT NNS [0.0855072],
#  DT -> 'the' [0.626263],
#  NNS -> 'flights' [0.746411],
#  NP* -> PP NP* [0.121076],
#  PP -> IN NP_NNP [0.349927],
#  IN -> 'from' [0.452282],
#  NP_NNP -> 'Baltimore' [0.0421286],
#  NP* -> PP SBAR [0.0112108],
#  PP -> TO NP_NNP [0.232796],
#  TO -> 'to' [1.0],
#  NP_NNP -> 'Seattle' [0.0133038],
#  SBAR -> WHNP_WDT S_VP [0.909091],
#  WHNP_WDT -> 'that' [0.428571],
#  S_VP -> VBP PP [0.0143885],
#  VBP -> 'stop' [0.0350877],
#  IN -> 'in' [0.10166],
#  NP_NNP -> 'Minneapolis' [0.0221729],
#  PUNC -> '.' [0.73774],
#  TOP -> SQ PUNC [0.0447761],
#  SQ -> VBZ SQ* [0.173333],
#  VBZ -> 'Does' [0.12069],
#  SQ* -> NP VP [0.132353],
#  NP -> DT NN [0.101449],
#  DT -> 'this' [0.0252525],
#  NN -> 'flight' [0.266904],
#  VP -> VB NP_NN [0.044586],
#  VB -> 'serve' [0.0421687],
#  NP_NN -> 'dinner' [0.27451],
#  PUNC -> '?' [0.26226],
#  TOP -> S PUNC [0.115139],
#  S -> NP_PRP VP [0.590164],
#  NP_PRP -> 'I' [0.323529],
#  VP -> VBP NP [0.10828],
#  VBP -> 'need' [0.140351],
#  DT -> 'a' [0.156566],
#  NP* -> VP VP [0.00224215],
#  VP -> VBG PP [0.0955414],
#  VBG -> 'leaving' [0.264706],
#  VP -> VBG NP [0.0382166],
#  VBG -> '<unk>' [0.117647],
#  NP -> NP PP [0.0405797],
#  NN -> 'stop' [0.024911],
#  VP -> VBP S_VP [0.0509554],
#  S_VP -> TO VP [0.151079],
#  VP -> VB S [0.0127389],
#  VB -> 'have' [0.0301205],
#  S -> NP_NN VP_VBN [0.0163934],
#  VP_VBN -> 'served' [1.0],
#  VBP -> 'have' [0.0614035],
#  NP -> NP SBAR [0.0188406],
#  NP -> CD NNS [0.00289855],
#  CD -> 'two' [0.0142857],
#  NNS -> '<unk>' [0.0239234],
#  S_VP -> MD VP [0.0143885],
#  MD -> 'would' [0.346154],
#  VP -> VB S_VP [0.0828025],
#  VB -> 'like' [0.10241],
#  VP -> VB VP* [0.127389],
#  VB -> 'visit' [0.0120482],
#  VP* -> NP_PRP VP* [0.0193548],
#  NP_PRP -> 'me' [0.602941],
#  VP* -> PP ADVP [0.00645161],
#  IN -> 'on' [0.143154],
#  NP_NNP -> 'Wednesday' [0.0243902],
#  ADVP -> ADVP_RB PP [0.285714],
#  ADVP_RB -> 'here' [0.125],
#  PP -> IN NP [0.288433],
#  NP -> NP_NNP NP [0.0130435],
#  NP_NNP -> 'Washington' [0.0177384],
#  NP -> NNP NNP [0.192754],
#  NNP -> 'D' [0.0122549],
#  NNP -> 'C' [0.0147059],
#  S -> S S* [0.0327869],
#  S -> NP VP [0.131148],
#  NP -> NP_CD PP [0.00144928],
#  NP_CD -> 'one' [1.0],
#  PP -> IN NP_PRP [0.00146413],
#  IN -> 'of' [0.0809129],
#  NP_PRP -> '<unk>' [0.0147059],
#  VP -> VBZ PP [0.0127389],
#  VBZ -> 'lives' [0.0344828],
#  NP_NNP -> 'Denver' [0.0332594],
#  S* -> CC S [0.25],
#  CC -> 'and' [0.804878],
#  NP -> DT JJ [0.00724638],
#  JJ -> 'other' [0.030303],
#  NP_NNP -> 'Miami' [0.0332594],
#  NN -> '<unk>' [0.0569395],
#  NP* -> VP SBAR [0.0044843],
#  VP* -> NP_PRP ADVP [0.00645161],
#  NP_NNP -> 'Indianapolis' [0.0243902],
#  NP* -> PP PP [0.242152],
#  NP_NNP -> 'Houston' [0.0354767],
#  NP -> NNP NP* [0.0463768],
#  NNP -> 'T' [0.00980392],
#  NP* -> NNP NNP [0.0605381],
#  NNP -> 'W' [0.0147059],
#  NNP -> 'A' [0.0245098],
#  DT -> 'The' [0.020202],
#  VP -> MD VP [0.121019],
#  MD -> 'should' [0.153846],
#  VB -> 'arrive' [0.0240964],
#  VP* -> PP NP_NN [0.00645161],
#  IN -> 'at' [0.0207469],
#  NP -> QP RB [0.00434783],
#  QP -> RB CD [0.214286],
#  RB -> 'around' [0.0566038],
#  CD -> 'eleven' [0.0142857],
#  RB -> 'a.m' [0.150943],
#  NP_NN -> 'tomorrow' [0.117647],
#  NP_NNP -> 'Atlanta' [0.0133038],
#  NP* -> PP NP [0.0134529],
#  PP -> TO NP [0.0849195],
#  NP_NNP -> 'Charlotte' [0.0199557],
#  NNP -> '<unk>' [0.00980392],
#  NP -> JJ NNP [0.00434783],
#  JJ -> 'next' [0.0909091],
#  NNP -> 'Monday' [0.0122549],
#  VP* -> PP PP [0.219355],
#  CD -> 'five' [0.128571],
#  RB -> 'p.m' [0.415094],
#  VP -> VB PP [0.044586],
#  VB -> 'return' [0.0120482],
#  NP_NNP -> 'Tuesday' [0.00886918],
#  NP -> DT NP* [0.084058],
#  NP* -> NN NN [0.0560538],
#  NN -> 'return' [0.00711744],
#  VB -> 'leave' [0.0240964],
#  CD -> 'seven' [0.0785714],
#  TOP -> SBARQ PUNC [0.217484],
#  SBARQ -> WHNP SQ [0.0784314],
#  WHNP -> WHNP ADJP_JJ [0.010989],
#  WHNP -> WRB RB [0.0549451],
#  WRB -> 'How' [1.0],
#  RB -> 'much' [0.0943396],
#  ADJP_JJ -> '<unk>' [0.333333],
#  SQ -> MD SQ* [0.0533333],
#  SQ* -> NP VP_VB [0.0588235],
#  NP* -> JJ NP* [0.029148],
#  JJ -> 'first' [0.151515],
#  NN -> 'class' [0.0498221],
#  NN -> 'fare' [0.0676157],
#  VP_VB -> 'cost' [0.5],
#  NN -> 'coach' [0.00711744],
#  VP -> VB NP [0.0955414],
#  VB -> 'find' [0.0120482],
#  S_VP -> VBZ VP* [0.0143885],
#  VBZ -> '<unk>' [0.0344828],
#  NP_NNP -> 'Boston' [0.0133038],
#  NP_NNP -> 'Orlando' [0.0310421],
#  VP -> TO VP [0.00636943],
#  VP -> VP VP* [0.0191083],
#  VB -> 'be' [0.0120482],
#  NNP -> 'United' [0.0147059],
#  NNP -> 'Airlines' [0.0416667],
#  VP* -> CC VP [0.0451613],
#  NNP -> 'San' [0.0735294],
#  NNP -> 'Jose' [0.0171569],
#  IN -> 'around' [0.0124481],
#  NP -> CD RB [0.0304348],
#  CD -> 'ten' [0.0785714],
#  VP* -> PRT_RP NP [0.00645161],
#  PRT_RP -> '<unk>' [1.0],
#  NN -> 'number' [0.0177936],
#  IN -> 'for' [0.0103734],
#  NP* -> NNP NN [0.00672646],
#  VBZ -> 'arrives' [0.0344828],
#  S_VP -> VB VP* [0.553957],
#  VB -> 'Show' [0.518072],
#  VP* -> NP_PRP NP [0.496774],
#  NP -> NP VP [0.0057971],
#  NP -> PDT NP* [0.00434783],
#  PDT -> 'all' [1.0],
#  NP* -> DT NNS [0.00672646],
#  VP -> VBG NP_NNP [0.00636943],
#  VB -> 'go' [0.0120482],
#  SBARQ -> PP SBARQ* [0.00980392],
#  IN -> '<unk>' [0.0124481],
#  DT -> 'those' [0.00505051],
#  SBARQ* -> WHNP_WHNP SQ_VP [1.0],
#  WHNP_WHNP -> WDT NNS [0.9],
#  WDT -> '<unk>' [0.0120482],
#  NNS -> 'ones' [0.00956938],
#  SQ_VP -> VBP PP [0.14],
#  DT -> 'that' [0.020202],
#  SBARQ -> WHNP_WP SQ [0.196078],
#  WHNP_WP -> 'What' [1.0],
#  SQ -> VBP NP [0.0666667],
#  VBP -> 'are' [0.236842],
#  NP_NNP -> 'Milwaukee' [0.0421286],
#  NP_NNP -> 'Tampa' [0.0310421],
#  SBARQ -> WHNP SQ_VP [0.411765],
#  WHNP -> WHNP_WDT PP [0.186813],
#  WHNP_WDT -> 'Which' [0.571429],
#  PP -> IN NP_DT [0.0161054],
#  NP_DT -> 'these' [0.533333],
#  NP_NNP -> 'Nashville' [0.037694],
#  NP_NNP -> 'Newark' [0.0620843],
#  NNP -> 'New' [0.0612745],
#  NNP -> 'Jersey' [0.00980392],
#  NNP -> 'Ontario' [0.00245098],
#  NNP -> 'International' [0.00490196],
#  NNP -> 'Saturday' [0.00245098],
#  SQ_VP -> VP VP* [0.04],
#  VP -> VBP PP [0.0318471],
#  VBP -> 'leave' [0.0964912],
#  PP -> IN NP_NN [0.0131772],
#  IN -> 'after' [0.033195],
#  NP_NN -> 'noon' [0.117647],
#  NP_NNP -> 'Phoenix' [0.0421286],
#  NP_NNP -> 'Montreal' [0.0177384],
#  NP_NNP -> 'Chicago' [0.0199557],
#  VB -> '<unk>' [0.0481928],
#  VP* -> NP_PRP PP [0.00645161],
#  IN -> 'about' [0.0124481],
#  NP* -> NN NP* [0.0224215],
#  NN -> 'ground' [0.0177936],
#  NN -> 'transportation' [0.024911],
#  TOP -> FRAG PUNC [0.0597015],
#  FRAG -> X PP [0.0689655],
#  X -> WP IN [0.666667],
#  WP -> 'What' [0.75],
#  SBARQ -> WHNP_WHNP SQ [0.186275],
#  WDT -> 'What' [0.915663],
#  SQ -> VBP SQ* [0.346667],
#  VBP -> 'do' [0.0438596],
#  SQ* -> NP_PRP VP [0.0882353],
#  NP_PRP -> 'you' [0.0441176],
#  S_VP -> VB NP_PRP [0.0143885],
#  VB -> 'Thank' [0.0120482],
#  WHNP -> WDT NN [0.032967],
#  WDT -> 'what' [0.0120482],
#  NN -> 'time' [0.00711744],
#  SQ -> VBZ NP_PRP [0.0266667],
#  VBZ -> 'is' [0.534483],
#  NP_PRP -> 'it' [0.0147059],
#  SBARQ -> WHNP_WDT SQ [0.0490196],
#  S_VP -> VBP NP [0.0143885],
#  VBP -> 'make' [0.0175439],
#  VB -> 'travel' [0.0180723],
#  NP -> CD NP* [0.0231884],
#  NP* -> CC NP* [0.00896861],
#  CC -> 'or' [0.170732],
#  NP* -> CD RB [0.00672646],
#  NP* -> JJ NN [0.0224215],
#  NN -> 'one' [0.00711744],
#  SQ -> VBZ NP [0.293333],
#  NN -> 'aircraft' [0.00711744],
#  VP -> VBN PP [0.0191083],
#  VBN -> '<unk>' [0.333333],
#  IN -> 'by' [0.00622407],
#  VP -> VBP ADJP [0.00636943],
#  VBP -> '<unk>' [0.0701754],
#  ADJP -> JJ PP [0.2],
#  JJ -> '<unk>' [0.19697],
#  NP_NNP -> 'Cincinnati' [0.0199557],
#  NP_NNP -> 'Burbank' [0.0133038],
#  VP -> VB NP_NNP [0.0127389],
#  NP_NNP -> 'American' [0.00443459],
#  NN -> 'afternoon' [0.0284698],
#  NP -> DT NX [0.00144928],
#  NX -> NX_NN NX* [0.5],
#  NX_NN -> 'aircraft' [1.0],
#  NX* -> CC NX [1.0],
#  NX -> NN NN [0.5],
#  NNP -> 'Los' [0.0269608],
#  NNP -> 'Angeles' [0.0269608],
#  NP* -> PP NP_NN [0.00672646],
#  NP_NN -> 'today' [0.0196078],
#  NP* -> PP VP [0.0224215],
#  NP -> NN NN [0.0130435],
#  NN -> 'today' [0.00355872],
#  NN -> 'evening' [0.0391459],
#  NN -> 'tomorrow' [0.0106762],
#  VBP -> 'Do' [0.0350877],
#  DT -> 'any' [0.00505051],
#  VB -> 'stop' [0.0060241],
#  WHNP -> WDT NNS [0.67033],
#  NNS -> 'meals' [0.0191388],
#  SQ_VP -> VBP VP [0.02],
#  VBN -> 'served' [0.666667],
#  DT -> 'these' [0.0555556],
#  VP* -> PP VP* [0.0709677],
#  VP* -> X_TO PP [0.00645161],
#  X_TO -> 'to' [1.0],
#  NP -> NP_NNP NP_NNP [0.00724638],
#  NP_NNP -> 'Tacoma' [0.0221729],
#  VB -> 'fly' [0.0301205],
#  NP_NNP -> 'July' [0.00665188],
#  SBARQ -> WHADVP_WRB SQ [0.00980392],
#  WHADVP_WRB -> '<unk>' [1.0],
#  VP_VB -> 'stop' [0.166667],
#  NN -> 'cost' [0.00711744],
#  JJ -> 'round' [0.227273],
#  NN -> 'trip' [0.0604982],
#  NP_NNP -> '<unk>' [0.0155211],
#  S -> INTJ_UH VP [0.0655738],
#  INTJ_UH -> 'Please' [0.25],
#  VB -> 'list' [0.0240964],
#  DT -> 'all' [0.0505051],
#  NP* -> NNP NP* [0.0515695],
#  NNP -> 'P' [0.00245098],
#  NP* -> CD NP* [0.044843],
#  CD -> 'fifty' [0.0428571],
#  NP* -> CD NN [0.00672646],
#  IN -> 'between' [0.026971],
#  NN -> 'type' [0.00711744],
#  NNP -> 'American' [0.0245098],
#  S -> INTJ_UH S* [0.0163934],
#  INTJ_UH -> 'Okay' [0.166667],
#  S* -> NP_PRP VP [0.625],
#  MD -> "'d" [0.384615],
#  VB -> 'make' [0.0060241],
#  NN -> 'reservation' [0.00711744],
#  NP -> NN NP* [0.0173913],
#  CD -> 'six' [0.0785714],
#  NP* -> CD CD [0.0381166],
#  CD -> 'oh' [0.0142857],
#  NP_NNP -> 'Delta' [0.00221729],
#  TOP -> FRAG_NP PUNC [0.223881],
#  FRAG_NP -> NP PP [0.0571429],
#  FRAG -> NP INTJ_UH [0.0344828],
#  NP -> NNP JJ [0.00289855],
#  NNP -> 'July' [0.00490196],
#  INTJ_UH -> 'please' [0.166667],
#  NP* -> NP_NN NP* [0.0044843],
#  NNP -> 'Diego' [0.0196078],
#  NP_NNP -> 'Toronto' [0.0221729],
#  NP_NNP -> 'Columbus' [0.0221729],
#  IN -> 'with' [0.0124481],
#  SQ_VP -> VBP NP [0.08],
#  NP* -> JJS NN [0.0156951],
#  JJS -> '<unk>' [0.125],
#  VBZ -> 'Is' [0.12069],
#  SQ* -> NP_NN VP [0.0147059],
#  NN -> 'leg' [0.00711744],
#  NP* -> CC NP [0.0336323],
#  SQ* -> NP PP [0.0147059],
#  SQ* -> NP_NP_EX NP [0.0294118],
#  NP_NP_EX -> 'there' [1.0],
#  NP* -> NP NP* [0.0044843],
#  NN -> 'morning' [0.0604982],
#  NP* -> X_TO PP [0.00224215],
#  NP -> NNP POS [0.00289855],
#  POS -> "'s" [1.0],
#  CD -> '<unk>' [0.05],
#  CD -> 'twenty' [0.0142857],
#  TOP -> INTJ_UH PUNC [0.00426439],
#  INTJ_UH -> 'Thanks' [0.166667],
#  NNP -> 'Kansas' [0.0343137],
#  NNP -> 'City' [0.0710784],
#  NN -> 'day' [0.0106762],
#  NP* -> NN NNS [0.0515695],
#  VP* -> ADVP NP [0.00645161],
#  ADVP -> RB PP [0.142857],
#  RB -> '<unk>' [0.0943396],
#  JJS -> 'latest' [0.125],
#  SBAR -> WHNP_WDT S [0.0454545],
#  S -> NP_NNP VP_VBZ [0.0163934],
#  VP_VBZ -> 'has' [1.0],
#  WDT -> 'Which' [0.060241],
#  VBP -> 'go' [0.0789474],
#  NNP -> 'York' [0.0514706],
#  CD -> 'twelve' [0.0357143],
#  NP_NN -> 'lunch' [0.0588235],
#  CD -> 'thirty' [0.0785714],
#  FRAG -> X NP [0.0689655],
#  X -> WRB IN [0.166667],
#  S_VP -> VBZ PP [0.0215827],
#  VBZ -> 'leaves' [0.0689655],
#  VP -> VBD NP [0.00636943],
#  VBD -> '<unk>' [1.0],
#  NNP -> 'Las' [0.0588235],
#  NNP -> 'Vegas' [0.0588235],
#  NP_NNP -> 'Sunday' [0.0177384],
#  S -> PP S* [0.0327869],
#  IN -> 'On' [0.00829876],
#  NP_NNP -> 'Monday' [0.0110865],
#  NP_NNP -> 'Detroit' [0.0133038],
#  MD -> 'Can' [0.0769231],
#  JJ -> 'nonstop' [0.151515],
#  NP_NNP -> 'Thursday' [0.00886918],
#  VP* -> ADVP_RB VP* [0.00645161],
#  ADVP_RB -> '<unk>' [0.25],
#  VP* -> PP ADJP [0.00645161],
#  ADJP -> RB ADJP* [0.2],
#  RB -> 'as' [0.0188679],
#  ADJP* -> RB PP [1.0],
#  PP -> IN ADJP_JJ [0.00146413],
#  IN -> 'as' [0.00207469],
#  VP* -> PP NP [0.0129032],
#  VB -> 'show' [0.0180723],
#  NP -> NN NNS [0.0101449],
#  S_VP -> VBP NP_NN [0.0143885],
#  VBP -> 'serve' [0.0438596],
#  FRAG -> NP FRAG* [0.0689655],
#  NP -> NP_NN NP* [0.00724638],
#  NP_NN -> 'Flight' [0.0784314],
#  NNP -> 'Saint' [0.0196078],
#  NNP -> 'Petersburg' [0.00735294],
#  NP* -> ADVP_RB NP [0.0044843],
#  NP_NN -> 'flight' [0.0588235],
#  FRAG* -> NP FRAG* [0.166667],
#  NP -> NP_NN PP [0.00144928],
#  NP_NN -> '<unk>' [0.0588235],
#  FRAG* -> NP NP [0.0833333],
#  NP -> JJ NN [0.015942],
#  NN -> 'airline' [0.00711744],
#  FRAG_NP -> NP NP* [0.219048],
#  NP_NN -> 'Airline' [0.0392157],
#  TOP -> FRAG_NP_NN PUNC [0.00426439],
#  FRAG_NP_NN -> '<unk>' [1.0],
#  NN -> 'Flight' [0.0106762],
#  NNS -> 'numbers' [0.0143541],
#  NNP -> 'Long' [0.00735294],
#  NNP -> 'Beach' [0.00735294],
#  S -> NP_PRP S* [0.0163934],
#  S* -> ADVP_RB VP [0.125],
#  VBP -> 'want' [0.0263158],
#  NP_NNP -> 'Ontario' [0.0133038],
#  VP -> VBP FRAG [0.00636943],
#  FRAG -> NP_NNP FRAG* [0.103448],
#  FRAG* -> PP PP [0.416667],
#  NP_NNP -> 'Westchester' [0.00221729],
#  IN -> 'via' [0.00622407],
#  SQ_VP -> VBZ NP_NN [0.02],
#  VBZ -> 'serves' [0.0344828],
#  NP -> CD CD [0.00289855],
#  NP -> NNP NN [0.0173913],
#  S -> ADVP_RB S* [0.0327869],
#  ADVP_RB -> 'Now' [0.125],
#  NNP -> 'Tuesday' [0.00245098],
#  NP_NNP -> 'Oakland' [0.0155211],
#  SQ_VP -> VBP NP_NN [0.08],
#  NN -> 'dinner' [0.0213523],
#  SQ_VP -> VBP ADVP_RB [0.02],
#  VBP -> 'depart' [0.0614035],
#  ADVP_RB -> 'last' [0.0625],
#  SQ_VP -> VBZ ADJP_JJ [0.06],
#  ADJP_JJ -> 'last' [0.333333],
#  SQ_VP -> VBP ADVP_RBS [0.02],
#  ADVP_RBS -> 'latest' [1.0],
#  NP* -> JJS NP* [0.00672646],
#  VP* -> NP INTJ_UH [0.0129032],
#  SBARQ -> WHNP_WDT SQ_VP [0.0588235],
#  SQ_VP -> VBZ ADVP_RBS [0.02],
#  WHNP_WHNP -> WHADJP NNS [0.1],
#  WHADJP -> WRB JJ [1.0],
#  JJ -> 'many' [0.0454545],
#  NNS -> 'fares' [0.0717703],
#  SQ* -> NP_NP_EX SQ* [0.25],
#  SQ* -> NP SQ* [0.0294118],
#  NP -> CD NN [0.0144928],
#  CD -> 'one' [0.185714],
#  NN -> 'way' [0.0284698],
#  SQ* -> PP PP [0.25],
#  JJS -> 'earliest' [0.09375],
#  NN -> 'lunch' [0.00711744],
#  VBG -> 'arriving' [0.352941],
#  WHNP -> WHNP PP [0.032967],
#  NP_NN -> 'aircraft' [0.0196078],
#  SQ_VP -> VBP VP* [0.36],
#  NP_NNP -> 'Dallas' [0.0310421],
#  TOP -> X_SBARQ PUNC [0.0021322],
#  X_SBARQ -> WHNP SQ_VP [1.0],
#  SQ_VP -> VBP PP_IN [0.02],
#  PP_IN -> 'from' [1.0],
#  NP_NNP -> 'Philadelphia' [0.0177384],
#  NNP -> 'Francisco' [0.0367647],
#  NP* -> SYM CD [0.00224215],
#  SYM -> 'D' [0.166667],
#  SQ_VP -> VBP ADJP_JJ [0.02],
#  ADJP_JJ -> 'nonstop' [0.222222],
#  NP -> QP NN [0.00289855],
#  QP -> IN QP* [0.142857],
#  QP* -> JJS CD [0.142857],
#  JJS -> 'least' [0.0625],
#  NP_NNP -> 'Pittsburgh' [0.0266075],
#  S_VP -> VBZ NP [0.00719424],
#  NP* -> SBAR PP [0.00224215],
#  NP -> JJ NNS [0.00724638],
#  NNS -> 'airlines' [0.0143541],
#  VBP -> 'fly' [0.0175439],
#  VP -> VBP VP* [0.0127389],
#  VP* -> NP_NNP PP [0.0322581],
#  VBP -> 'arrive' [0.0350877],
#  NN -> 'noon' [0.00711744],
#  SQ -> X SQ* [0.0133333],
#  X -> VBZ NP_DT [0.166667],
#  NP_DT -> 'this' [0.0666667],
#  SQ* -> VBZ SQ* [0.0147059],
#  SQ* -> NP ADJP_JJ [0.0147059],
#  SQ* -> NP NP [0.0294118],
#  CD -> 'four' [0.0214286],
#  NP -> NP_NNP NP* [0.00869565],
#  NNP -> 'Salt' [0.0147059],
#  NNP -> 'Lake' [0.0147059],
#  NP -> NP ADJP_JJ [0.00144928],
#  TOP -> SBAR PUNC [0.0021322],
#  SBAR -> WHNP SQ [0.0454545],
#  WHNP -> WHADJP NNS [0.010989],
#  NNS -> 'stops' [0.0191388],
#  SQ -> VBP NP_NP_EX [0.0133333],
#  DT -> 'Any' [0.00505051],
#  NNS -> 'stopovers' [0.00956938],
#  NNP -> 'Delta' [0.00245098],
#  NP* -> X_JJ NNS [0.00224215],
#  X_JJ -> 'nonstop' [1.0],
#  NNP -> 'Louis' [0.00735294],
#  IN -> 'before' [0.026971],
#  NP -> NP_DT PP [0.00289855],
#  NP_DT -> 'any' [0.0666667],
#  VP -> VB NP_NNS [0.00636943],
#  NP_NNS -> 'stops' [0.0144928],
#  SQ* -> NP_DT NP [0.0147059],
#  SQ* -> PP SQ* [0.0294118],
#  NP_NNP -> 'Saturday' [0.0155211],
#  VP* -> NP_NNP VP* [0.0129032],
#  CD -> 'nine' [0.05],
#  S_VP -> VB NP_NNS [0.0143885],
#  NP_NNS -> 'flights' [0.231884],
#  NNP -> 'N' [0.00490196],
#  NP_NNP -> 'Memphis' [0.0310421],
#  NP -> NP_NNS NP* [0.0188406],
#  FRAG_NP -> NP_NNS NP* [0.333333],
#  NP_NNS -> 'Flights' [0.594203],
#  NP_NNP -> 'Cleveland' [0.059867],
#  TOP -> FRAG_VP PUNC [0.0170576],
#  FRAG_VP -> VBG VP* [0.75],
#  VBG -> 'Leaving' [0.117647],
#  NP_NNS -> '<unk>' [0.0144928],
#  FRAG_VP -> VBG PP [0.125],
#  FRAG -> PP VP [0.0344828],
#  NP -> JJ NP* [0.0130435],
#  JJ -> 'Last' [0.030303],
#  NN -> 'night' [0.00711744],
#  NNP -> 'Thursday' [0.0147059],
#  NP_NNP -> 'Friday' [0.0199557],
#  NNP -> 'U' [0.00980392],
#  NNP -> 'S' [0.00735294],
#  NNP -> 'Air' [0.00735294],
#  FRAG_NP -> JJS NN [0.0380952],
#  NN -> 'nonstop' [0.00711744],
#  FRAG_NP -> NP VP_VBG [0.00952381],
#  VP_VBG -> '<unk>' [1.0],
#  PP -> IN PP* [0.00146413],
#  PP* -> CC PP* [0.25],
#  PP* -> IN NP [0.25],
#  CD -> 'eight' [0.0285714],
#  S_VP -> VBZ ADVP_RB [0.00719424],
#  ADVP_RB -> 'first' [0.0625],
#  NP -> NP SBAR_S_VP [0.00144928],
#  JJ -> 'last' [0.0151515],
#  SBAR_S_VP -> TO VP_VB [1.0],
#  VP_VB -> 'leave' [0.166667],
#  NP -> NP_NNS PP [0.00434783],
#  VP -> VBG VP* [0.0254777],
#  PP -> PP PP* [0.00146413],
#  PP* -> CC PP [0.25],
#  S_VP -> VBP ADVP [0.00719424],
#  ADVP -> NP RB [0.571429],
#  NP -> QP NNS [0.0101449],
#  QP -> RBR QP* [0.285714],
#  RBR -> 'less' [1.0],
#  QP* -> IN CD [0.285714],
#  IN -> 'than' [0.0145228],
#  NNS -> 'minutes' [0.0239234],
#  RB -> 'apart' [0.0754717],
#  NP -> NP NNS [0.00144928],
#  NNP -> 'Sunday' [0.00490196],
#  NP -> NP_NNS VP [0.00289855],
#  NP* -> NNS PP [0.00224215],
#  DT -> '<unk>' [0.010101],
#  S -> ADVP_RB VP [0.0327869],
#  ADVP_RB -> 'Only' [0.125],
#  NP* -> VP ADVP [0.00672646],
#  NP* -> CC NP_NNP [0.00896861],
#  TOP -> NP PUNC [0.00639659],
#  FRAG -> ADVP_RB NP_NNP [0.0344828],
#  FRAG -> NP_NNP PP [0.172414],
#  FRAG_NP -> NNP NN [0.0190476],
#  NP* -> CD NNS [0.00672646],
#  CD -> 'hundred' [0.0571429],
#  NNS -> 'hours' [0.0191388],
#  NNP -> 'Wednesday' [0.00980392],
#  NP* -> NNP NNS [0.0112108],
#  FRAG_NP -> NP_NNS PP [0.0666667],
#  TOP -> FRAG_NP_NNP PUNC [0.0021322],
#  FRAG_NP_NNP -> 'Tuesday' [1.0],
#  FRAG -> PP PP [0.137931],
#  IN -> 'From' [0.0103734],
#  NNP -> 'Friday' [0.00735294],
#  NNP -> 'Cincinnati' [0.00245098],
#  NP* -> CC NNP [0.00672646],
#  NNP -> 'Tampa' [0.00245098],
#  FRAG_NP -> NN NNS [0.00952381],
#  NP -> JJS NP* [0.0057971],
#  JJS -> 'Shortest' [0.09375],
#  VP* -> NP PP [0.0129032],
#  FRAG -> PP FRAG* [0.0344828],
#  FRAG* -> PP VP [0.0833333],
#  VBG -> 'departing' [0.0882353],
#  TOP -> FRAG_WHNP PUNC [0.0703625],
#  FRAG_WHNP -> WHNP WHNP* [0.939394],
#  WHNP* -> PP WHNP* [0.438596],
#  WHNP* -> PP PP [0.561404],
#  FRAG_WHNP -> NP WHNP* [0.030303],
#  NP -> WDT NNS [0.00144928],
#  CD -> 'forty' [0.0142857],
#  FRAG -> WHNP PP [0.0344828],
#  FRAG -> WHNP FRAG* [0.0689655],
#  NN -> 'price' [0.0391459],
#  SQ_VP -> VBP NP_NNS [0.02],
#  NP_NNS -> 'meals' [0.0144928],
#  FRAG_WHNP -> WHNP PP [0.030303],
#  NP* -> NN SYM [0.0044843],
#  NN -> 'code' [0.00711744],
#  SYM -> '<unk>' [0.5],
#  TOP -> FRAG_PP PUNC [0.010661],
#  FRAG_PP -> IN NP_NNP [0.2],
#  SQ* -> NP_PRP VP_VB [0.0147059],
#  VP_VB -> '<unk>' [0.166667],
#  FRAG_NP -> NP_NN PP [0.0571429],
#  NP_NN -> 'Price' [0.137255],
#  FRAG -> NP_NN FRAG* [0.0344828],
#  FRAG* -> PP FRAG* [0.0833333],
#  FRAG* -> PP NP [0.0833333],
#  NP* -> CC NP_NN [0.00224215],
#  NP_NN -> 'price' [0.0196078],
#  FRAG_NP -> NP_NN NP* [0.0380952],
#  CD -> 'three' [0.0142857],
#  NP -> JJS NN [0.0115942],
#  PP -> NP PP* [0.00146413],
#  PP* -> IN S_VP_VBG [0.25],
#  S_VP_VBG -> 'arriving' [1.0],
#  JJ -> 'First' [0.030303],
#  JJS -> 'Cheapest' [0.40625],
#  NN -> 'airfare' [0.0177936],
#  SQ -> INTJ_UH SQ* [0.0133333],
#  INTJ_UH -> '<unk>' [0.166667],
#  SQ* -> MD SQ* [0.0147059],
#  MD -> '<unk>' [0.0384615],
#  NP_DT -> 'those' [0.266667],
#  SQ_VP -> VBZ NP [0.02],
#  NP -> CC NP* [0.00144928],
#  CC -> '<unk>' [0.0243902],
#  SQ_VP -> VBP NP_NNP [0.02],
#  FRAG -> X NP_NNP [0.0344828],
#  WP -> 'what' [0.25],
#  NP_DT -> 'Any' [0.0666667],
#  SQ_VP -> VBZ ADJP_JJR [0.04],
#  ADJP_JJR -> 'better' [1.0],
#  FRAG_VP -> VBG NP [0.125],
#  NNP -> 'Westchester' [0.00980392],
#  NNP -> 'County' [0.00980392],
#  NNP -> 'Paul' [0.00490196],
#  NNP -> 'Newark' [0.00245098],
#  NNP -> 'Cleveland' [0.00490196],
#  NNP -> 'Ohio' [0.00490196],
#  FRAG_NP -> JJ NP* [0.00952381],
#  JJ -> 'Round' [0.030303],
#  FRAG_NP -> DT NNS [0.00952381],
#  FRAG_NP -> NN NP* [0.0380952],
#  NN -> 'Return' [0.00711744],
#  DT -> 'All' [0.020202],
#  TOP -> FRAG_ADJP_JJ PUNC [0.00426439],
#  FRAG_ADJP_JJ -> 'Nonstop' [1.0],
#  FRAG_NP -> CD NNS [0.00952381],
#  FRAG_NP -> JJ NNS [0.00952381],
#  NN -> 'business' [0.00711744],
#  NNP -> 'J' [0.00980392],
#  NNP -> 'F' [0.0147059],
#  NNP -> 'K' [0.00980392],
#  FRAG_NP -> NP_NNP NP* [0.00952381],
#  FRAG_PP -> IN NP [0.8],
#  IN -> 'With' [0.00622407],
#  NP* -> ADJP NN [0.00224215],
#  ADJP -> RBS JJ [0.2],
#  RBS -> 'least' [1.0],
#  FRAG -> NP NP [0.0689655],
#  FRAG_NP -> JJS NP* [0.0190476],
#  TOP -> ADJP_JJ PUNC [0.0021322],
#  ADJP_JJ -> 'Nonstop' [0.111111],
#  FRAG_NP -> NN NN [0.0285714],
#  NN -> 'Ground' [0.0106762],
#  NNP -> 'Milwaukee' [0.00245098],
#  NNP -> 'Orlando' [0.00245098],
#  PP -> IN NP_NNPS [0.00146413],
#  NP_NNPS -> 'Wednesdays' [1.0],
#  NP -> NP NP [0.00289855],
#  TOP -> FRAG_ADJP_JJS PUNC [0.0021322],
#  FRAG_ADJP_JJS -> 'Cheapest' [1.0],
#  VBG -> 'Departing' [0.0588235],
#  PP -> IN NP_NNS [0.00439239],
#  NP_NNS -> 'Wednesdays' [0.0144928],
#  NP* -> RB RB [0.00896861],
#  RB -> "o'clock" [0.0943396],
#  NP -> NNP NNS [0.00144928],
#  NP_NNS -> 'weekdays' [0.0434783],
#  NP* -> PP NP_NNS [0.00224215],
#  ADVP_RB -> 'daily' [0.25],
#  NP* -> NP ADVP_RB [0.00224215],
#  FRAG* -> PP ADVP_RB [0.0833333],
#  NP* -> PP ADVP_RB [0.00224215],
#  NP_NNS -> 'Airports' [0.0289855],
#  NNP -> 'La' [0.00735294],
#  NNP -> 'Guardia' [0.00735294],
#  NN -> 'Coach' [0.0106762],
#  S -> NP_NN VP [0.0163934],
#  VP -> VBZ NP [0.00636943],
#  NP* -> PP ADJP [0.00224215],
#  ADJP -> JJR PP [0.4],
#  JJR -> 'less' [0.75],
#  QP -> CD QP* [0.214286],
#  QP* -> CD CD [0.285714],
#  NNS -> 'dollars' [0.0191388],
#  NP_NNS -> 'Fares' [0.0289855],
#  NP -> QP NP* [0.00144928],
#  NP* -> NNS QP [0.00224215],
#  QP -> CC JJR [0.0714286],
#  FRAG_NP -> NP_NNS ADJP [0.00952381],
#  QP* -> CD QP* [0.142857],
#  NP_NNS -> 'fares' [0.0144928],
#  QP -> RB QP* [0.0714286],
#  QP* -> JJR QP* [0.0714286],
#  JJR -> '<unk>' [0.25],
#  QP* -> IN QP* [0.0714286],
#  FRAG_NP -> JJS NNS [0.00952381],
#  NP* -> JJS NNS [0.00224215],
#  JJS -> 'cheapest' [0.09375],
#  S_VP -> VP VP* [0.0143885],
#  NP* -> JJ NNS [0.00224215],
#  TOP -> X_S_VP PUNC [0.0021322],
#  X_S_VP -> VB VP* [1.0],
#  PP -> TO INTJ_UH [0.00146413],
#  INTJ_UH -> 'oh' [0.0833333],
#  NNP -> 'Southwest' [0.00980392],
#  NP -> RB NP* [0.00144928],
#  NP* -> DT NP* [0.00224215],
#  S_VP -> VBP VP* [0.00719424],
#  VP* -> RB VP [0.00645161],
#  NP_NNP -> 'Dulles' [0.00221729],
#  NNP -> 'Dulles' [0.00245098],
#  S_VP -> VBZ NP_NN [0.00719424],
#  VBZ -> 'has' [0.0172414],
#  VB -> 'Explain' [0.0180723],
#  NNS -> 'codes' [0.00956938],
#  NP* -> SYM NP* [0.00672646],
#  SYM -> 'A' [0.166667],
#  SYM -> 'P' [0.166667]]

# %% [markdown]
# ## 05 - Import Sentences to parse
#
# Next, I create a list named sentences by reading all the lines from the dev.strings file. Each line in the file corresponds to a single sentence, and these are stored as individual elements in the list.
#
# This prepares the development data for parsing by organizing the raw sentences into a structured list.

# %%
with open('dev.strings') as file:
    sentences = file.read()
    sentences = sentences.split('\n')

sentences
# Out:
# ['The flight should be eleven a.m tomorrow .',
#  'I would like it to have a stop in New York and I would like a flight that serves breakfast .',
#  'Which of these serve dinner ?',
#  'Which ones stop in Nashville ?',
#  'Are there any flights arriving after eleven a.m ?',
#  'What flights do you have from Ontario ?',
#  'Where does this flight stop ?',
#  "What type of aircraft is Alaska 's flight two eighty two ?",
#  'Does the other American flight ?',
#  "I 'd like to fly from Tampa to Montreal .",
#  "On Tuesday I 'd like to fly from Detroit to Saint Petersburg .",
#  'Flight from Long Beach to Columbus on twenty seventh .',
#  'Which ones leave in the morning ?',
#  'Which of these flights serve dinner ?',
#  'Which is last ?',
#  'Show me all the fares from one way fares from Tacoma to Montreal .',
#  'Which flights serve breakfast ?',
#  'What airline provides only connecting flights between Denver and San Francisco ?',
#  'List all flights from Burbank to Denver .',
#  'Are there any stopovers for Delta one seven three nine ?',
#  'What is M I A ?',
#  'What flights leave from Phoenix to anywhere ?',
#  'What flights are there from Houston to Dallas ?',
#  'What flights are there from Memphis to Las Vegas ?',
#  'Flights from Cleveland to Miami .',
#  'Flights on Sunday from Tampa to Charlotte .',
#  'Show me flights that leave in the morning .',
#  'Flights arriving in Las Vegas from Memphis and New York City on Sunday .',
#  'Display flights arriving within thirty minutes of each other .',
#  'Show me the fare .',
#  "What 's the earliest flight from Dallas to Houston ?",
#  'From Toronto to Atlanta in the afternoon .',
#  'What flights from Kansas City to Denver .',
#  'What flights from Washington D C to Toronto .',
#  'Are any of those on American Airlines ?',
#  'What flights from Montreal to Las Vegas on Saturday .',
#  'What is the price ?',
#  'On Thursday .',
#  'Flights from Cleveland to Kansas City .',
#  'Price from Cleveland to Kansas City round trip .',
#  'Flights from Ontario to Florida .',
#  'First class round trip airfare from Indianapolis to Memphis .',
#  'Flights from Boston to Pittsburgh .',
#  "What 's the cheapest ?",
#  'Restriction code A P slash five seven .',
#  'Flights from New York to Miami .',
#  'Departing before ten a.m .',
#  'Cheapest fare .',
#  'Departing after six p.m .',
#  "Departing Wednesday after five o'clock .",
#  'Show me ground transportation in Westchester County .',
#  'Newark to Cleveland .',
#  'Airline T W A .',
#  'Fares .',
#  'Show me the fares .',
#  'Show me the fares from Dallas to San Francisco .',
#  'Show me the flights from San Diego to San Francisco on Southwest Airlines .',
#  'Show me the restrictions .',
#  '']

# %% [markdown]
# ## 06 - CKY Parsing with Unknown Word Handling
#
# ### Objective
#
# I then implemented a function named `cky_parsing` to apply the CKY algorithm for sentence parsing using a given Probabilistic Context-Free Grammar (PCFG). This function uses the Viterbi parsing algorithm and accounts for unknown words by replacing them with `<unk>`, ensuring compatibility with the grammar's productions.
#
# ### Key Steps in the Implementation:
#
# 1. Function Definition:
# The function cky_parsing takes two arguments:
#     - `sentences`: a list of raw sentence strings to parse
#     - `grammar`: the PCFG used by the parser
#
# 2. Preprocessing Known Words:
#
# Inside the function, I construct a set of known words by scanning all terminal productions in the grammar. This set is used to identify which words in a sentence are covered by the grammar. Any word not found in this set is replaced with `<unk>` during parsing.
#
# 3. Initializing the Viterbi Parser:
#
# I initialize a ViterbiParser using the NLTK library, passing the PCFG as the grammar input.
#
# 4. Parsing Sentences:
#
# For each sentence in the list:
#
#     - The sentence is tokenized (split by whitespace).
#     - Unknown words are replaced with `<unk>`.
#     - The parser attempts to generate all possible parses using parse_all().
#     - The most probable parse is selected from the results. If no parse is found, the output reflects that appropriately.
#
# 5. Return Value:
#
#     - The function returns a list of tuples, one for each sentence. Each tuple contains:
#     - The index of the sentence
#     - The original sentence string
#     - The best parse tree found, or an appropriate fallback value if parsing fails

# %%
def cky_parsing(sentences, grammar):
    import re
    string = str(grammar.productions())
    production_set = set(re.findall(r"'([A-Za-z0-9_\./\\-]*)'", string))
    
    tokenized = []
    for sentence in sentences:
        words = sentence.split()
        tokenized.append(words)

    new_tokenized = []
    for line in tokenized:
        new_words = []
        for word in line:
            if word not in production_set:
                new_word = '<unk>'
                new_words.append(new_word)
            else:
                new_words.append(word)
        new_tokenized.append(new_words)
    
    
    parser = ViterbiParser(grammar)
    
    parsed = []
    for line in new_tokenized:
        parse = parser.parse_all(line)
        parsed.append(parse)
    
    tuples = []
    for i in range(len(sentences)):
        try:
            tuple = (i, sentences[i], parsed[i][0])
            tuples.append(tuple)
        except:
            tuple = (i, sentences[i], parsed[i])
            tuples.append(tuple)
    
    return tuples

# %% [markdown]
# ## 07 - Executing CKY Parsing Function on Sentences
#
# Now parse and print the results.

# %%
cky_charts = cky_parsing(sentences, grammar)

for index, sentence, chart in cky_charts:
    print(f"Line {index}: {sentence}")

    if chart:
        print(f"Probability: {math.log(chart.prob())}")  # Using log probability
        print("Parse:")
        chart.pretty_print()  # Pretty print the parse tree      
    else:
        print("No parse available for this sentence")
    print("-------------------------------------------------")
# Out:
# Line 0: The flight should be eleven a.m tomorrow .
# No parse available for this sentence
# -------------------------------------------------
# Line 1: I would like it to have a stop in New York and I would like a flight that serves breakfast .
# Probability: -85.26919694246591
# Parse:
#                                                            TOP
#                _____________________________________________|______________________________________________________________________
#               S                                                                                                                    |
#    ___________|_______________                                                                                                     |
#   |                           VP                                                                                                   |
#   |       ____________________|_____________________________                                                                       |
#   |      |                                                  VP                                                                     |
#   |      |     _____________________________________________|____                                                                  |
#   |      |    |                                                  S                                                                 |
#   |      |    |            ______________________________________|____                                                             |
#   |      |    |           |                                           S*                                                           |
#   |      |    |           |                                       ____|______                                                      |
#   |      |    |           S                                      |           S                                                     |
#   |      |    |      _____|___                                   |     ______|____                                                 |
#   |      |    |     |         VP                                 |    |           VP                                               |
#   |      |    |     |      ___|____________                      |    |       ____|_____________                                   |
#   |      |    |     |     |                VP                    |    |      |                  VP                                 |
#   |      |    |     |     |    ____________|____                 |    |      |     _____________|_______                           |
#   |      |    |     |     |   |                 NP               |    |      |    |                     NP                         |
#   |      |    |     |     |   |         ________|___             |    |      |    |         ____________|_______                   |
#   |      |    |     |     |   |        |            PP           |    |      |    |        |                   SBAR                |
#   |      |    |     |     |   |        |         ___|___         |    |      |    |        |             _______|_____             |
#   |      |    |     |     |   |        NP       |       NP       |    |      |    |        NP           |            S_VP          |
#   |      |    |     |     |   |     ___|___     |    ___|___     |    |      |    |     ___|____        |        _____|______      |
# NP_PRP   MD   VB  NP_PRP  TO VBP   DT      NN   IN NNP     NNP   CC NP_PRP   MD   VB   DT       NN   WHNP_WDT  VBZ        ADVP_RB PUNC
#   |      |    |     |     |   |    |       |    |   |       |    |    |      |    |    |        |       |       |            |     |
#   I    would like   it    to have  a      stop  in New     York and   I    would like  a      flight   that   serves       <unk>   .
#
# -------------------------------------------------
# Line 2: Which of these serve dinner ?
# No parse available for this sentence
# -------------------------------------------------
# Line 3: Which ones stop in Nashville ?
# No parse available for this sentence
# -------------------------------------------------
# Line 4: Are there any flights arriving after eleven a.m ?
# No parse available for this sentence
# -------------------------------------------------
# Line 5: What flights do you have from Ontario ?
# No parse available for this sentence
# -------------------------------------------------
# Line 6: Where does this flight stop ?
# No parse available for this sentence
# -------------------------------------------------
# Line 7: What type of aircraft is Alaska 's flight two eighty two ?
# No parse available for this sentence
# -------------------------------------------------
# Line 8: Does the other American flight ?
# No parse available for this sentence
# -------------------------------------------------
# Line 9: I 'd like to fly from Tampa to Montreal .
# Probability: -34.03716346858472
# Parse:
#                       TOP
#           _____________|________________________________________
#          S                                                      |
#    ______|____                                                  |
#   |           VP                                                |
#   |       ____|____                                             |
#   |      |         VP                                           |
#   |      |     ____|_______                                     |
#   |      |    |           S_VP                                  |
#   |      |    |     _______|_________                           |
#   |      |    |    |                 VP                         |
#   |      |    |    |    _____________|_____                     |
#   |      |    |    |   |                  VP*                   |
#   |      |    |    |   |         __________|_______             |
#   |      |    |    |   |        PP                 PP           |
#   |      |    |    |   |    ____|____           ___|_____       |
# NP_PRP   MD   VB   TO  VB  IN      NP_NNP      TO      NP_NNP  PUNC
#   |      |    |    |   |   |         |         |         |      |
#   I    <unk> like  to fly from     Tampa       to     Montreal  .
#
# -------------------------------------------------
# Line 10: On Tuesday I 'd like to fly from Detroit to Saint Petersburg .
# Probability: -56.27894913674751
# Parse:
#                                       TOP
#             ___________________________|______________________________________________
#            S                                                                          |
#       _____|_____________                                                             |
#      |                   S*                                                           |
#      |             ______|____                                                        |
#      |            |           VP                                                      |
#      |            |       ____|____                                                   |
#      |            |      |         VP                                                 |
#      |            |      |     ____|___                                               |
#      |            |      |    |       S_VP                                            |
#      |            |      |    |     ___|_______________                               |
#      |            |      |    |    |                   VP                             |
#      |            |      |    |    |    _______________|_____                         |
#      |            |      |    |    |   |                    VP*                       |
#      |            |      |    |    |   |          ___________|____                    |
#      |            |      |    |    |   |         |                PP                  |
#      |            |      |    |    |   |         |            ____|____               |
#      PP           |      |    |    |   |         PP          |         NP             |
#   ___|_____       |      |    |    |   |     ____|_____      |     ____|______        |
#  IN      NP_NNP NP_PRP   MD   VB   TO  VB   IN       NP_NNP  TO  NNP         NNP     PUNC
#  |         |      |      |    |    |   |    |          |     |    |           |       |
#  On     Tuesday   I    <unk> like  to fly  from     Detroit  to Saint     Petersburg  .
#
# -------------------------------------------------
# Line 11: Flight from Long Beach to Columbus on twenty seventh .
# Probability: -42.84490372214105
# Parse:
#                               TOP
#                 _______________|_____________________________________
#             FRAG_NP                                                  |
#    ____________|_______________                                      |
#   |                            PP                                    |
#   |      ______________________|_________                            |
#   |     |                                NP                          |
#   |     |             ___________________|______                     |
#   |     |            |                         NP*                   |
#   |     |            |              ____________|____                |
#   |     |            |             |                 PP              |
#   |     |            |             |             ____|_____          |
#   |     |            NP            PP           |          NP        |
#   |     |       _____|____      ___|_____       |     _____|____     |
# NP_NN   IN    NNP        NNP   TO      NP_NNP   IN   CD         RB  PUNC
#   |     |      |          |    |         |      |    |          |    |
# Flight from   Long      Beach  to     Columbus  on twenty     <unk>  .
#
# -------------------------------------------------
# Line 12: Which ones leave in the morning ?
# No parse available for this sentence
# -------------------------------------------------
# Line 13: Which of these flights serve dinner ?
# No parse available for this sentence
# -------------------------------------------------
# Line 14: Which is last ?
# No parse available for this sentence
# -------------------------------------------------
# Line 15: Show me all the fares from one way fares from Tacoma to Montreal .
# Probability: -51.33429661880188
# Parse:
#                                     TOP
#                   ___________________|__________________________________________________________
#                 S_VP                                                                            |
#   _______________|___________________                                                           |
#  |                                  VP*                                                         |
#  |      _____________________________|_______                                                   |
#  |     |                                     NP                                                 |
#  |     |          ___________________________|________                                          |
#  |     |         |                                   NP*                                        |
#  |     |         |                        ____________|____________________                     |
#  |     |         |                       PP                                |                    |
#  |     |         |               ________|___                              |                    |
#  |     |         NP             |            NP                           NP*                   |
#  |     |      ___|____          |     _______|___                __________|_______             |
#  |     |     |       NP*        |    |          NP*             PP                 PP           |
#  |     |     |    ____|____     |    |        ___|____      ____|____           ___|_____       |
#  VB  NP_PRP PDT  DT       NNS   IN   CD      NN      NNS   IN      NP_NNP      TO      NP_NNP  PUNC
#  |     |     |   |         |    |    |       |        |    |         |         |         |      |
# Show   me   all the      fares from one     way     fares from     Tacoma      to     Montreal  .
#
# -------------------------------------------------
# Line 16: Which flights serve breakfast ?
# No parse available for this sentence
# -------------------------------------------------
# Line 17: What airline provides only connecting flights between Denver and San Francisco ?
# No parse available for this sentence
# -------------------------------------------------
# Line 18: List all flights from Burbank to Denver .
# Probability: -28.31879842076823
# Parse:
#                       TOP
#        ________________|___________________________________
#      S_VP                                                  |
#   ____|________________                                    |
#  |                     NP                                  |
#  |          ___________|________________                   |
#  |         |                           NP*                 |
#  |         |                 ___________|_______           |
#  |         NP               PP                  PP         |
#  |     ____|_____       ____|_____           ___|____      |
#  VB   DT        NNS    IN       NP_NNP      TO     NP_NNP PUNC
#  |    |          |     |          |         |        |     |
# List all      flights from     Burbank      to     Denver  .
#
# -------------------------------------------------
# Line 19: Are there any stopovers for Delta one seven three nine ?
# No parse available for this sentence
# -------------------------------------------------
# Line 20: What is M I A ?
# No parse available for this sentence
# -------------------------------------------------
# Line 21: What flights leave from Phoenix to anywhere ?
# No parse available for this sentence
# -------------------------------------------------
# Line 22: What flights are there from Houston to Dallas ?
# No parse available for this sentence
# -------------------------------------------------
# Line 23: What flights are there from Memphis to Las Vegas ?
# No parse available for this sentence
# -------------------------------------------------
# Line 24: Flights from Cleveland to Miami .
# Probability: -14.358259491284384
# Parse:
#                                TOP
#                       __________|______________
#                   FRAG_NP                      |
#     _________________|______                   |
#    |                       NP*                 |
#    |           _____________|_______           |
#    |          PP                    PP         |
#    |      ____|______            ___|____      |
#  NP_NNS  IN        NP_NNP       TO     NP_NNP PUNC
#    |     |           |          |        |     |
# Flights from     Cleveland      to     Miami   .
#
# -------------------------------------------------
# Line 25: Flights on Sunday from Tampa to Charlotte .
# Probability: -24.663094271810696
# Parse:
#                            TOP
#             ________________|_____________________________________
#         FRAG_NP                                                   |
#     _______|________________                                      |
#    |                       NP*                                    |
#    |              __________|_______________                      |
#    |             |                         NP*                    |
#    |             |                __________|_______              |
#    |             PP              PP                 PP            |
#    |        _____|____       ____|____           ___|______       |
#  NP_NNS    IN       NP_NNP  IN      NP_NNP      TO       NP_NNP  PUNC
#    |       |          |     |         |         |          |      |
# Flights    on       Sunday from     Tampa       to     Charlotte  .
#
# -------------------------------------------------
# Line 26: Show me flights that leave in the morning .
# No parse available for this sentence
# -------------------------------------------------
# Line 27: Flights arriving in Las Vegas from Memphis and New York City on Sunday .
# Probability: -59.46067052833196
# Parse:
#                                                         TOP
#                                                     _____|____________________________________
#                                                 FRAG_NP                                       |
#                    ________________________________|_________                                 |
#                   |                                         NP*                               |
#                   |                           _______________|___                             |
#                   NP                         |                  NP*                           |
#     ______________|___                       |            _______|________                    |
#    |                  VP                     |           |                NP                  |
#    |        __________|___                   |           |        ________|________           |
#    |       |              PP                 |           |       NP                |          |
#    |       |       _______|___               |           |    ___|____             |          |
#    |       |      |           NP             PP          |   |       NP*           PP         |
#    |       |      |        ___|____      ____|_____      |   |    ____|___      ___|____      |
#  NP_NNS   VBG     IN     NNP      NNP   IN       NP_NNP  CC NNP NNP      NNP   IN     NP_NNP PUNC
#    |       |      |       |        |    |          |     |   |   |        |    |        |     |
# Flights arriving  in     Las     Vegas from     Memphis and New York     City  on     Sunday  .
#
# -------------------------------------------------
# Line 28: Display flights arriving within thirty minutes of each other .
# Probability: -50.39735832602076
# Parse:
#                                       TOP
#               _________________________|_________________________________
#              S                                                           |
#         _____|_______________                                            |
#        |                     VP                                          |
#        |              _______|_________________                          |
#        |             |                         NP                        |
#        |             |                  _______|__________               |
#        |             |                 NP                 PP             |
#        |             |             ____|_______       ____|____          |
#        NP            |            QP           |     |         NP        |
#    ____|_____        |        ____|____        |     |     ____|____     |
#   JJ        NNS     VBG      RB        CD     NNS    IN   DT        JJ  PUNC
#   |          |       |       |         |       |     |    |         |    |
# <unk>     flights arriving <unk>     thirty minutes  of <unk>     other  .
#
# -------------------------------------------------
# Line 29: Show me the fare .
# Probability: -9.773761130880418
# Parse:
#                  TOP
#               ____|____________
#             S_VP               |
#   ___________|____             |
#  |               VP*           |
#  |      __________|___         |
#  |     |              NP       |
#  |     |           ___|___     |
#  VB  NP_PRP       DT      NN  PUNC
#  |     |          |       |    |
# Show   me        the     fare  .
#
# -------------------------------------------------
# Line 30: What 's the earliest flight from Dallas to Houston ?
# No parse available for this sentence
# -------------------------------------------------
# Line 31: From Toronto to Atlanta in the afternoon .
# Probability: -32.41455499744773
# Parse:
#                                   TOP
#                              ______|______________________
#                            FRAG                           |
#        _____________________|______                       |
#       |                          FRAG*                    |
#       |                ____________|____                  |
#       |               |                 PP                |
#       |               |             ____|___              |
#       PP              PP           |        NP            |
#   ____|_____       ___|_____       |     ___|______       |
#  IN       NP_NNP  TO      NP_NNP   IN   DT         NN    PUNC
#  |          |     |         |      |    |          |      |
# From     Toronto  to     Atlanta   in  the     afternoon  .
#
# -------------------------------------------------
# Line 32: What flights from Kansas City to Denver .
# Probability: -18.938937713375072
# Parse:
#                                       TOP
#                             ___________|___________________
#                        FRAG_WHNP                           |
#        ____________________|___________                    |
#       |                              WHNP*                 |
#       |                     ___________|________           |
#       |                    PP                   |          |
#       |             _______|______              |          |
#      WHNP          |              NP            PP         |
#   ____|______      |        ______|____      ___|____      |
# WDT         NNS    IN     NNP         NNP   TO     NP_NNP PUNC
#  |           |     |       |           |    |        |     |
# What      flights from   Kansas       City  to     Denver  .
#
# -------------------------------------------------
# Line 33: What flights from Washington D C to Toronto .
# Probability: -30.321051417500744
# Parse:
#                                        TOP
#                             ____________|____________________________
#                        FRAG_WHNP                                     |
#        ____________________|____________                             |
#       |                               WHNP*                          |
#       |                             ____|________________            |
#       |                            PP                    |           |
#       |             _______________|____                 |           |
#       |            |                    NP               |           |
#       |            |        ____________|____            |           |
#      WHNP          |       |                 NP          PP          |
#   ____|______      |       |             ____|___     ___|_____      |
# WDT         NNS    IN    NP_NNP        NNP      NNP  TO      NP_NNP PUNC
#  |           |     |       |            |        |   |         |     |
# What      flights from Washington       D        C   to     Toronto  .
#
# -------------------------------------------------
# Line 34: Are any of those on American Airlines ?
# No parse available for this sentence
# -------------------------------------------------
# Line 35: What flights from Montreal to Las Vegas on Saturday .
# Probability: -28.016594790689915
# Parse:
#                                                TOP
#                                          _______|_______________________________
#                                     FRAG_WHNP                                   |
#        _________________________________|_______                                |
#       |                                       WHNP*                             |
#       |                  _______________________|_________                      |
#       |                 |                               WHNP*                   |
#       |                 |                        _________|________             |
#       |                 |                       PP                 |            |
#       |                 |                _______|____              |            |
#      WHNP               PP              |            NP            PP           |
#   ____|______       ____|_____          |        ____|____      ___|_____       |
# WDT         NNS    IN       NP_NNP      TO     NNP       NNP   IN      NP_NNP  PUNC
#  |           |     |          |         |       |         |    |         |      |
# What      flights from     Montreal     to     Las      Vegas  on     Saturday  .
#
# -------------------------------------------------
# Line 36: What is the price ?
# No parse available for this sentence
# -------------------------------------------------
# Line 37: On Thursday .
# Probability: -15.97158949314833
# Parse:
#               TOP
#         _______|______
#     FRAG_PP           |
#   _____|_______       |
#  IN          NP_NNP  PUNC
#  |             |      |
#  On         Thursday  .
#
# -------------------------------------------------
# Line 38: Flights from Cleveland to Kansas City .
# Probability: -19.62582720313387
# Parse:
#                            TOP
#                       ______|___________________
#                   FRAG_NP                       |
#     _________________|______                    |
#    |                       NP*                  |
#    |           _____________|____               |
#    |          |                  PP             |
#    |          |              ____|_____         |
#    |          PP            |          NP       |
#    |      ____|______       |     _____|___     |
#  NP_NNS  IN        NP_NNP   TO  NNP       NNP  PUNC
#    |     |           |      |    |         |    |
# Flights from     Cleveland  to Kansas     City  .
#
# -------------------------------------------------
# Line 39: Price from Cleveland to Kansas City round trip .
# Probability: -33.49940663742464
# Parse:
#                                   TOP
#                              ______|_________________________________
#                          FRAG_NP                                     |
#    _________________________|______                                  |
#   |                               NP*                                |
#   |          ______________________|_________                        |
#   |         |                                PP                      |
#   |         |                ________________|____                   |
#   |         |               |                     NP                 |
#   |         |               |             ________|_________         |
#   |         PP              |            NP                NP*       |
#   |     ____|______         |       _____|___           ____|___     |
# NP_NN  IN        NP_NNP     TO    NNP       NNP        JJ       NN  PUNC
#   |    |           |        |      |         |         |        |    |
# Price from     Cleveland    to   Kansas     City     round     trip  .
#
# -------------------------------------------------
# Line 40: Flights from Ontario to Florida .
# Probability: -16.624476940107556
# Parse:
#                              TOP
#                      _________|______________
#                  FRAG_NP                     |
#     ________________|_____                   |
#    |                     NP*                 |
#    |           ___________|_______           |
#    |          PP                  PP         |
#    |      ____|_____           ___|____      |
#  NP_NNS  IN       NP_NNP      TO     NP_NNP PUNC
#    |     |          |         |        |     |
# Flights from     Ontario      to     <unk>   .
#
# -------------------------------------------------
# Line 41: First class round trip airfare from Indianapolis to Memphis .
# Probability: -42.74625489735171
# Parse:
#                                        TOP
#                                    _____|_________________________________________
#                                FRAG_NP                                            |
#                    _______________|___________________________                    |
#                   NP                                          |                   |
#         __________|____                                       |                   |
#        |              NP*                                    NP*                  |
#        |           ____|____                  ________________|_______            |
#        NP         |        NP*               PP                       PP          |
#    ____|____      |     ____|_____       ____|_______              ___|_____      |
#   JJ        NN    JJ   NN         NN    IN         NP_NNP         TO      NP_NNP PUNC
#   |         |     |    |          |     |            |            |         |     |
# First     class round trip     airfare from     Indianapolis      to     Memphis  .
#
# -------------------------------------------------
# Line 42: Flights from Boston to Pittsburgh .
# Probability: -16.085480439374866
# Parse:
#                              TOP
#                      _________|__________________
#                  FRAG_NP                         |
#     ________________|_____                       |
#    |                     NP*                     |
#    |           ___________|_______               |
#    |          PP                  PP             |
#    |      ____|_____           ___|______        |
#  NP_NNS  IN       NP_NNP      TO       NP_NNP   PUNC
#    |     |          |         |          |       |
# Flights from      Boston      to     Pittsburgh  .
#
# -------------------------------------------------
# Line 43: What 's the cheapest ?
# No parse available for this sentence
# -------------------------------------------------
# Line 44: Restriction code A P slash five seven .
# Probability: -40.51715309572969
# Parse:
#                             TOP
#                        ______|_______________________
#                    FRAG_NP                           |
#         ______________|______                        |
#        |                    NP*                      |
#        |         ____________|____                   |
#        |        |                NP*                 |
#        |        |      ___________|___               |
#        |        |     |              NP*             |
#        |        |     |       ________|____          |
#        NP       |     |      |            NP*        |
#    ____|___     |     |      |         ____|____     |
#   JJ       NN  NNP   SYM     JJ       CD        CD  PUNC
#   |        |    |     |      |        |         |    |
# <unk>     code  A     P    <unk>     five     seven  .
#
# -------------------------------------------------
# Line 45: Flights from New York to Miami .
# Probability: -19.14136739656581
# Parse:
#                          TOP
#                  _________|___________________
#              FRAG_NP                          |
#     ____________|_________                    |
#    |                     NP*                  |
#    |             _________|________           |
#    |            PP                 |          |
#    |      ______|_____             |          |
#    |     |            NP           PP         |
#    |     |       _____|___      ___|____      |
#  NP_NNS  IN    NNP       NNP   TO     NP_NNP PUNC
#    |     |      |         |    |        |     |
# Flights from   New       York  to     Miami   .
#
# -------------------------------------------------
# Line 46: Departing before ten a.m .
# Probability: -22.071032674864018
# Parse:
#                          TOP
#                      _____|___________
#                  FRAG_VP              |
#      _______________|_____            |
#     |                     PP          |
#     |        _____________|___        |
#     |       |                 NP      |
#     |       |              ___|___    |
#    VBG      IN            CD      RB PUNC
#     |       |             |       |   |
# Departing before         ten     a.m  .
#
# -------------------------------------------------
# Line 47: Cheapest fare .
# Probability: -8.663174636220438
# Parse:
#                  TOP
#              _____|____
#          FRAG_NP       |
#     ________|_____     |
#   JJS             NN  PUNC
#    |              |    |
# Cheapest         fare  .
#
# -------------------------------------------------
# Line 48: Departing after six p.m .
# Probability: -20.851792398407294
# Parse:
#                         TOP
#                     _____|___________
#                 FRAG_VP              |
#      ______________|_____            |
#     |                    PP          |
#     |        ____________|___        |
#     |       |                NP      |
#     |       |             ___|___    |
#    VBG      IN           CD      RB PUNC
#     |       |            |       |   |
# Departing after         six     p.m  .
#
# -------------------------------------------------
# Line 49: Departing Wednesday after five o'clock .
# Probability: -27.196720256195114
# Parse:
#                                 TOP
#                         _________|______________
#                     FRAG_VP                     |
#      __________________|_____                   |
#     |                       VP*                 |
#     |          ______________|___               |
#     |         |                  PP             |
#     |         |         _________|____          |
#     |         |        |              NP        |
#     |         |        |          ____|____     |
#    VBG      NP_NNP     IN        CD        RB  PUNC
#     |         |        |         |         |    |
# Departing Wednesday  after      five     <unk>  .
#
# -------------------------------------------------
# Line 50: Show me ground transportation in Westchester County .
# Probability: -34.0146820476418
# Parse:
#                             TOP
#         _____________________|____________________________________
#       S_VP                                                        |
#   _____|_____________________                                     |
#  |                          VP*                                   |
#  |      _____________________|_________                           |
#  |     |                               NP                         |
#  |     |             __________________|_______                   |
#  |     |            |                          PP                 |
#  |     |            |                   _______|_______           |
#  |     |            NP                 |               NP         |
#  |     |       _____|________          |        _______|____      |
#  VB  NP_PRP   NN             NN        IN     NNP          NNP   PUNC
#  |     |      |              |         |       |            |     |
# Show   me   ground     transportation  in Westchester     County  .
#
# -------------------------------------------------
# Line 51: Newark to Cleveland .
# Probability: -11.932904129388387
# Parse:
#             TOP
#          ____|_____________
#        FRAG                |
#    _____|____              |
#   |          PP            |
#   |      ____|______       |
# NP_NNP  TO        NP_NNP  PUNC
#   |     |           |      |
# Newark  to      Cleveland  .
#
# -------------------------------------------------
# Line 52: Airline T W A .
# Probability: -26.629620274856467
# Parse:
#                     TOP
#                 _____|___________
#             FRAG_NP              |
#     ___________|_____            |
#    |                NP*          |
#    |      ___________|___        |
#    |     |              NP*      |
#    |     |            ___|___    |
#  NP_NN  NNP         NNP     NNP PUNC
#    |     |           |       |   |
# Airline  T           W       A   .
#
# -------------------------------------------------
# Line 53: Fares .
# No parse available for this sentence
# -------------------------------------------------
# Line 54: Show me the fares .
# Probability: -9.885087289719353
# Parse:
#                  TOP
#               ____|_____________
#             S_VP                |
#   ___________|____              |
#  |               VP*            |
#  |      __________|___          |
#  |     |              NP        |
#  |     |           ___|____     |
#  VB  NP_PRP       DT      NNS  PUNC
#  |     |          |        |    |
# Show   me        the     fares  .
#
# -------------------------------------------------
# Line 55: Show me the fares from Dallas to San Francisco .
# Probability: -28.79951143075871
# Parse:
#                            TOP
#               ______________|_____________________________________
#             S_VP                                                  |
#   ___________|______________                                      |
#  |                         VP*                                    |
#  |      ____________________|_________                            |
#  |     |                              NP                          |
#  |     |           ___________________|_____                      |
#  |     |          |                        NP*                    |
#  |     |          |               __________|___                  |
#  |     |          |              |              PP                |
#  |     |          |              |           ___|___              |
#  |     |          NP             PP         |       NP            |
#  |     |      ____|____      ____|____      |    ___|______       |
#  VB  NP_PRP  DT       NNS   IN      NP_NNP  TO NNP        NNP    PUNC
#  |     |     |         |    |         |     |   |          |      |
# Show   me   the      fares from     Dallas  to San     Francisco  .
#
# -------------------------------------------------
# Line 56: Show me the flights from San Diego to San Francisco on Southwest Airlines .
# Probability: -46.11462609149707
# Parse:
#                                           TOP
#                         ___________________|_____________________________________________________
#                       S_VP                                                                       |
#   _____________________|___________________                                                      |
#  |                                        VP*                                                    |
#  |      ___________________________________|____                                                 |
#  |     |                                        NP                                               |
#  |     |          ______________________________|___                                             |
#  |     |         |                                 NP*                                           |
#  |     |         |                 _________________|__________                                  |
#  |     |         |                |                           NP*                                |
#  |     |         |                |                  __________|_____________                    |
#  |     |         |                PP                PP                       PP                  |
#  |     |         |            ____|___           ___|___               ______|______             |
#  |     |         NP          |        NP        |       NP            |             NP           |
#  |     |      ___|_____      |     ___|____     |    ___|______       |       ______|_____       |
#  VB  NP_PRP  DT       NNS    IN  NNP      NNP   TO NNP        NNP     IN    NNP          NNP    PUNC
#  |     |     |         |     |    |        |    |   |          |      |      |            |      |
# Show   me   the     flights from San     Diego  to San     Francisco  on Southwest     Airlines  .
#
# -------------------------------------------------
# Line 57: Show me the restrictions .
# Probability: -9.945611387807077
# Parse:
#                  TOP
#               ____|_____________
#             S_VP                |
#   ___________|____              |
#  |               VP*            |
#  |      __________|___          |
#  |     |              NP        |
#  |     |           ___|____     |
#  VB  NP_PRP       DT       NN  PUNC
#  |     |          |        |    |
# Show   me        the     <unk>  .
#
# -------------------------------------------------
# Line 58:
# No parse available for this sentence
# -------------------------------------------------

# %% [markdown]
# ### 08 - Export Grammar
#
# To preserve the grammar for future use or analysis, I export the induced grammar using Python’s `pickle` library. This serializes the grammar object and saves it to a file within the working directory of the notebook.

# %%
# Importing dill library for model serialization
import dill

# Serialization with dill
with open('grammar.dill', 'wb') as file:
    dill.dump(grammar , file)
